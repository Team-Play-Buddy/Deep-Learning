# %% [markdown]
# ### <b>배우 정보 추출 및 특징 벡터 추출 자동화</b> ###

# %% [markdown]
# #### Step 1. 배우 정보 API를 활용하여 <b>특정한 배우</b> 정보 출력

# %%
import requests
import json

# 배우 정보 API URL (ID 1인 배우 정보 가져오기)
actor_id = 1
url = f"http://52.78.226.136:4000/actor/{actor_id}"

try:
    # API 요청 보내기
    response = requests.get(url)

    # 상태 코드 확인
    if response.status_code == 200:
        actor_data = response.json()  # JSON 데이터 파싱
        print("배우 정보:")
        print(json.dumps(actor_data, indent=4))
    else:
        print(f"API 요청 실패: 상태 코드 {response.status_code}")
except requests.exceptions.RequestException as e:
    print(f"요청 중 오류 발생: {e}")
# Out:
# 배우 정보:
# {
#     "success": true,
#     "data": {
#         "userId": 1,
#         "username": "feature1",
#         "password": "feature1",
#         "userType": "actor",
#         "createdAt": "2025-03-24T11:37:27.779Z",
#         "updatedAt": "2025-03-28T20:47:40.116Z",
#         "userEmails": [
#             {
#                 "userEmailId": 1,
#                 "email": "zkfzmfh17@naver.com",
#                 "isVerified": true,
#                 "verificationDate": "2025-03-24T11:37:28.000Z",
#                 "createdAt": "2025-03-24T11:37:27.800Z"
#             }
#         ],
#         "actorProfile": {
#             "userId": 1,
#             "nameKo": "\uae40\ub2e4\ube48",
#             "nameEn": "",
#             "age": 27,
#             "height": "179",
#             "weight": "72",
#             "isActive": true,
#             "gender": "male"
#         },
#         "actorDetails": {
#             "userId": 1,
#             "contact": "",
#             "instagram": null,
#             "youtube": null,
#             "agency": "",
#             "bio": "\ub9e1\uaca8 \uc8fc\uc2e0\ub2e4\uba74 \uc88b\uc740 \uc5f0\uae30 \ubcf4\uc5ec\ub4dc\ub9ac\uaca0\uc2b5\ub2c8\ub2e4!\n\uac10\uc0ac\ud569\ub2c8\ub2e4!",
#             "career": "\ub2e8\ud3b8 \uc601\ud654 '\ub9c8\uc911 \uac00\ub294 \uae38' \uad8c\ubbfc\uc900 \uc5ed - \uc8fc\uc5f0\n\ub2e8\ud3b8 \uc601\ud654 '\uc5f4\uc544\ud649' \ubc31\ubbfc\uc900 \uc5ed-\uc8fc\uc5f0\n\ub2e8\ud3b8 \uc601\ud654'\uc0ac\ub77c\uc84c\ub2e4 \ud55c\ub4e4 \ub5a0\uc624\ub974\ub294 \uac83' \uba85\uc218 \uc5ed-\uc8fc\uc5f0\n\ub2e8\ud3b8\uc601\ud654'\uc2e0\ud638' \ub3c4\uc601 \uc5ed-\uc8fc\uc5f0",
#             "education": "",
#             "specialSkills": "\uc57c\uad6c, \uc218\uc601(\uc790\uc720\ud615)",
#             "familyInfo": ""
#         },
#         "actorInstagram": null,
#         "profileImages": [
#             {
#                 "imageId": 1,
#                 "imageUrl": "https://playbuddy.s3.ap-northeast-2.amazonaws.com/actors/1/1_1.jpg",
#                 "uploadedAt": "2025-03-24T12:04:42.000Z"
#             },
#             {
#                 "imageId": 2,
#                 "imageUrl": "https://playbuddy.s3.ap-northeast-2.amazonaws.com/actors/1/1_2.jpg",
#                 "uploadedAt": "2025-03-24T12:04:42.000Z"
#             },
#             {
#                 "imageId": 3,
#                 "imageUrl": "https://playbuddy.s3.ap-northeast-2.amazonaws.com/actors/1/1_3.jpg",
#                 "uploadedAt": "2025-03-24T12:04:42.000Z"
#             },
#             {
#                 "imageId": 4,
#                 "imageUrl": "https://playbuddy.s3.ap-northeast-2.amazonaws.com/actors/1/1_4.jpg",
#                 "uploadedAt": "2025-03-24T12:04:42.000Z"
#             },
#             {
#                 "imageId": 5,
#                 "imageUrl": "https://playbuddy.s3.ap-northeast-2.amazonaws.com/actors/1/1_5.jpg",
#                 "uploadedAt": "2025-03-24T12:04:42.000Z"
#             },
#             {
#                 "imageId": 6,
#                 "imageUrl": "https://playbuddy.s3.ap-northeast-2.amazonaws.com/actors/1/1_6.jpg",
#                 "uploadedAt": "2025-03-24T12:04:42.000Z"
#             },
#             {
#                 "imageId": 7,
#                 "imageUrl": "https://playbuddy.s3.ap-northeast-2.amazonaws.com/actors/1/1_7.jpg",
#                 "uploadedAt": "2025-03-24T12:04:42.000Z"
#             },
#             {
#                 "imageId": 8,
#                 "imageUrl": "https://playbuddy.s3.ap-northeast-2.amazonaws.com/actors/1/1_8.jpg",
#                 "uploadedAt": "2025-03-24T12:04:42.000Z"
#             }
#         ]
#     }
# }

# %%
import requests
import json
from IPython.display import display, HTML

# 배우 정보 API URL
actor_id = 1
url = f"http://52.78.226.136:4000/actor/{actor_id}"

try:
    # API 요청 보내기
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        if data.get("success") and "data" in data:
            actor = data["data"]
            profile = actor.get("actorProfile", {})
            images = actor.get("profileImages", [])

            # 배우 주요 정보
            actor_info = f"""
            <h2>배우 정보</h2>
            <p><strong>이름:</strong> {profile.get('nameKo', 'N/A')}</p>
            <p><strong>나이:</strong> {profile.get('age', 'N/A')}세</p>
            <p><strong>키:</strong> {profile.get('height', 'N/A')}cm</p>
            <p><strong>몸무게:</strong> {profile.get('weight', 'N/A')}kg</p>
            <p><strong>성별:</strong> {'남성' if profile.get('gender') == 'male' else '여성'}</p>
            """

            # 프로필 이미지 출력 (최대 3개)
            image_html = "<h3>프로필 사진</h3>"
            for img in images[:3]:  # 최대 3장만 출력
                image_html += f'<img src="{img["imageUrl"]}" width="150" style="margin-right:10px;">'

            # HTML 출력
            display(HTML(actor_info + image_html))

        else:
            print("배우 정보를 찾을 수 없습니다.")

    else:
        print(f"API 요청 실패: 상태 코드 {response.status_code}")

except requests.exceptions.RequestException as e:
    print(f"요청 중 오류 발생: {e}")

# %%
import requests
from IPython.display import display, HTML

# 배우 정보 API URL
actor_id = 1
url = f"http://52.78.226.136:4000/actor/{actor_id}"

try:
    # API 요청 보내기
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        if data.get("success") and "data" in data:
            actor = data["data"]
            profile = actor.get("actorProfile", {})
            details = actor.get("actorDetails", {})

            # 경력, 자기소개 줄바꿈 처리
            career = details.get("career", "N/A").replace("\n", "<br>")
            bio = details.get("bio", "N/A").replace("\n", "<br>")

            # 배우 메인 정보
            main_info = """
            <h2>📌 메인 정보</h2>
            <ul>
                <li><strong>이름:</strong> {}</li>
                <li><strong>나이:</strong> {}세</li>
                <li><strong>키:</strong> {}cm</li>
                <li><strong>몸무게:</strong> {}kg</li>
                <li><strong>성별:</strong> {}</li>
            </ul>
            """.format(
                profile.get("nameKo", "N/A"),
                profile.get("age", "N/A"),
                profile.get("height", "N/A"),
                profile.get("weight", "N/A"),
                "남성" if profile.get("gender") == "male" else "여성"
            )

            # 배우 부가 정보
            extra_info = """
            <h2>📌 부가 정보</h2>
            <ul>
                <li><strong>경력:</strong><br> {}</li>
                <li><strong>특기:</strong> {}</li>
                <li><strong>자기소개:</strong><br> {}</li>
            </ul>
            """.format(
                career,
                details.get("specialSkills", "N/A"),
                bio
            )

            # HTML 출력
            display(HTML(main_info + extra_info))

        else:
            print("배우 정보를 찾을 수 없습니다.")

    else:
        print(f"API 요청 실패: 상태 코드 {response.status_code}")

except requests.exceptions.RequestException as e:
    print(f"요청 중 오류 발생: {e}")

# %% [markdown]
# #### Step 2. <b>다수의 배우</b> 정보 출력

# %%
import requests
from IPython.display import display, HTML

# 배우 정보 API URL (1~30번 배우)
actor_ids = range(1, 11)
base_url = "http://52.78.226.136:4000/actor/{}"

# HTML을 저장할 리스트
html_blocks = []

for actor_id in actor_ids:
    try:
        response = requests.get(base_url.format(actor_id))

        if response.status_code == 200:
            data = response.json()

            if data.get("success") and "data" in data:
                actor = data["data"]
                profile = actor.get("actorProfile", {})
                details = actor.get("actorDetails", {})

                # 경력, 자기소개 줄바꿈 처리
                career = details.get("career", "N/A").replace("\n", "<br>")
                bio = details.get("bio", "N/A").replace("\n", "<br>")

                # 배우 메인 정보
                main_info = """
                <h2>📌 배우 {}</h2>
                <h3>메인 정보</h3>
                <ul>
                    <li><strong>이름:</strong> {}</li>
                    <li><strong>나이:</strong> {}세</li>
                    <li><strong>키:</strong> {}cm</li>
                    <li><strong>몸무게:</strong> {}kg</li>
                    <li><strong>성별:</strong> {}</li>
                </ul>
                """.format(
                    actor_id,
                    profile.get("nameKo", "N/A"),
                    profile.get("age", "N/A"),
                    profile.get("height", "N/A"),
                    profile.get("weight", "N/A"),
                    "남성" if profile.get("gender") == "male" else "여성"
                )

                # 배우 부가 정보
                extra_info = """
                <h3>부가 정보</h3>
                <ul>
                    <li><strong>경력:</strong><br> {}</li>
                    <li><strong>특기:</strong> {}</li>
                    <li><strong>자기소개:</strong><br> {}</li>
                </ul>
                <hr>
                """.format(
                    career,
                    details.get("specialSkills", "N/A"),
                    bio
                )

                # 리스트에 HTML 추가
                html_blocks.append(main_info + extra_info)

            else:
                html_blocks.append(f"<h2>📌 배우 {actor_id}</h2><p>배우 정보를 찾을 수 없습니다.</p><hr>")

        else:
            html_blocks.append(f"<h2>📌 배우 {actor_id}</h2><p>API 요청 실패 (상태 코드: {response.status_code})</p><hr>")

    except requests.exceptions.RequestException as e:
        html_blocks.append(f"<h2>📌 배우 {actor_id}</h2><p>요청 중 오류 발생: {e}</p><hr>")

# 최종 출력
display(HTML("".join(html_blocks)))

# %% [markdown]
# #### 실험 1. <b>gogamza/kobart-summarization</b>

# %%
# 모델과 문장 분리를 위한 토크나이저를 불러옵니다.
from transformers import PreTrainedTokenizerFast, BartForConditionalGeneration
tokenizer = PreTrainedTokenizerFast.from_pretrained("gogamza/kobart-summarization")
model = BartForConditionalGeneration.from_pretrained("gogamza/kobart-summarization")

# 요약하고자 하는 기사를 입력합니다.
# 기사원문: http://news.heraldcorp.com/view.php?ud=20211127000015
news_text = "세계가 ‘오미크론(Omicron)’ 공포에 빠졌다. 코로나19 델타변이도 잡지 못해 전전긍긍하는데 세계보건기구(WHO)가 또 다른 ‘우려 변이(variant of concern)’로 오미크론을 지정하면서다. 항체를 무력화 수 있는 돌연변이가 많은 걸로 파악되는 오미크론이 코로나19 백신엔 어떤 영향을 미칠지를 보려면 추가 연구가 필요한 상황이다. 각 국은 서둘러 국경의 빗장을 걸고 있다. 미국과 유럽 등 글로벌 증시를 폭락시킨 오미크론은 현재로선 어디로 튈지 모르는 변이여서 두려움을 더하고 있다."

# 토크나이저를 사용하여 뉴스기사 원문을 모델이 인식할 수 있는 토큰형태로 바꿔줍니다.
input_ids = tokenizer.encode(news_text)

import torch

# 모델에 넣기 전 문장의 시작과 끝을 나타내는 토큰을 추가합니다.
input_ids = [tokenizer.bos_token_id] + input_ids + [tokenizer.eos_token_id]
input_ids = torch.tensor([input_ids])

summary_text_ids = model.generate(
    input_ids=input_ids,
    bos_token_id=model.config.bos_token_id,
    eos_token_id=model.config.eos_token_id,
    length_penalty=1.0, # 길이에 대한 penalty값. 1보다 작은 경우 더 짧은 문장을 생성하도록 유도하며, 1보다 클 경우 길이가 더 긴 문장을 유도
    max_length=128,     # 요약문의 최대 길이 설정
    min_length=32,      # 요약문의 최소 길이 설정
    num_beams=4,        # 문장 생성시 다음 단어를 탐색하는 영역의 개수
)

print(tokenizer.decode(summary_text_ids[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer.json:   0%|          | 0.00/682k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels will be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels will be overwritten to 2.
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# 세계보건기구(WHO)가 항체를 무력화 할 수 있는 돌연변이가 많은 걸로 파악되는 오미크론이 코로나19 백신엔 어떤 영향을 미칠지를 보려면 추가 연구가 필요한 상황이다.

# %%
import requests
# import torch
# from transformers import PreTrainedTokenizerFast, BartForConditionalGeneration

# KoBART 요약 모델 로드
# tokenizer = PreTrainedTokenizerFast.from_pretrained("gogamza/kobart-summarization")
# model = BartForConditionalGeneration.from_pretrained("gogamza/kobart-summarization")

# 배우 정보 API URL (1~10번 배우)
actor_ids = range(1, 11)
base_url = "http://52.78.226.136:4000/actor/{}"

# 최종 정리된 텍스트 저장 리스트
actor_texts = []

def summarize_text(text):
    """KoBART 모델을 이용해 텍스트 요약"""
    input_ids = tokenizer.encode(text, truncation=True, max_length=512)  # 모델 입력 최대 길이 제한
    input_ids = [tokenizer.bos_token_id] + input_ids + [tokenizer.eos_token_id]
    input_ids = torch.tensor([input_ids])

    summary_ids = model.generate(
        input_ids=input_ids,
        bos_token_id=model.config.bos_token_id,
        eos_token_id=model.config.eos_token_id,
        length_penalty=1.0,
        max_length=128,  # 요약문의 최대 길이
        min_length=32,   # 요약문의 최소 길이
        num_beams=4      # 빔 서치 사용
    )

    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

for actor_id in actor_ids:
    try:
        response = requests.get(base_url.format(actor_id))

        if response.status_code == 200:
            data = response.json()

            if data.get("success") and "data" in data:
                actor = data["data"]
                profile = actor.get("actorProfile", {})
                details = actor.get("actorDetails", {})

                # 📌 메인 정보 (단순 문자열 합치기)
                main_info = f"{profile.get('nameKo', 'N/A')}, {profile.get('age', 'N/A')}세, {profile.get('height', 'N/A')}cm, {profile.get('weight', 'N/A')}kg, {'남성' if profile.get('gender') == 'male' else '여성'}"

                # 📌 부가 정보 (요약 모델 사용)
                extra_text = f"경력: {details.get('career', 'N/A')}. 특기: {details.get('specialSkills', 'N/A')}. 자기소개: {details.get('bio', 'N/A')}"
                summary = summarize_text(extra_text)

                # 최종 텍스트 저장
                actor_texts.append(f"메인 정보: {main_info}. 부가 정보: {summary.strip()}") # 불필요한 공백 제거 이후 출력

            else:
                actor_texts.append(f"배우 {actor_id}: 정보 없음")

        else:
            actor_texts.append(f"배우 {actor_id}: API 요청 실패 (상태 코드 {response.status_code})")

    except requests.exceptions.RequestException as e:
        actor_texts.append(f"배우 {actor_id}: 요청 중 오류 발생 - {e}")

# 결과 출력
for text in actor_texts:
    print(text)
# Out:
# 메인 정보: 김다빈, 27세, 179cm, 72kg, 남성. 부가 정보: 영화 '마중 가는 길' 권민준 역은 야구, 수영(자유형). 자기소개: 맡겨 주신다면 좋은 연기 보여드리겠습니다펍감사합니다
# 메인 정보: 전민서, 23세, 179cm, 64kg, 남성. 부가 정보: 경력: 볼링, 골프, 수영, 그림, 복싱, 볼링, 골프, 골프, 골프, 골프, 골프, 수영, 그림, 복싱. 자기소개: 잘 부탁드립니다!
# 메인 정보: 송마루, 21세, 178cm, 63kg, 남성. 부가 정보: 현재 경기대학교 연기학과에 재학중이며 현재 경기대학교 연기학과에 재학중인 경력: 연극배우우리읍내- 무대감독
# 아름다운 사인 - 남자
#
# 음악극 뮤지컬
# 메인 정보: 김제국, 24세, 171cm, 65kg, 남성. 부가 정보: 배우지망하는 김제국씨는 짜증내는 연기와 바보연기, 능청스러운 연기 자신있다며 많은 관심부탁드리며 긴 글 읽어주셔서 감사하다고 전했다.
# 메인 정보: 박성훈, 25세, 177cm, 65kg, 남성. 부가 정보: 경력: . 특기: 사투리 가능. 자기소개: 연기와 모델일 이제 배우기 시작했습니다펍기회가 있으면 열심히 해보고 싶습니다 잘 부탁 드립니다!
# 메인 정보: 임건표, 31세, 177cm, 130kg, 남성. 부가 정보: 안녕하세요 신인배우 임건표는 길들여진새 - 멀티역. 특기: 보컬, 오토바이운전. 자기소개: 안녕하세요 신인배우 임건표 입니다.
# 메인 정보: 김민서, 23세, 175cm, 61kg, 남성. 부가 정보: 경력: 경력: 경력이 없습니다. 특기: . 자기소개: 경력은 없습니다 경험 해보고싶어 올려봅니다 경험 해보고싶어 올려봅니다
# 메인 정보: 이윤선, 29세, 177cm, 68kg, 남성. 부가 정보: 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역
# 메인 정보: 리아즈  / Riaz(외국인, 외국), 33세, 169cm, 68kg, 남성. 부가 정보: 샨토마리암 대학교 행사 - 모델, 연기, 모델링, 댄스, 스포츠(축구, 크리켓, 배드민턴, 두뇌 게임 ), 요리. 자기소개: Contact me for more details.
# 메인 정보: 오혁, 15세, 165cm, 49kg, 남성. 부가 정보: 2018~20113~20일 치뤄지는 드라마 '베트맨버스터'의 피팅모델과 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델, 피팅모델로 구성된다.

# %% [markdown]
# #### 실험 2. <b>digit82/kobart-summarization

# %%
import requests
import torch
from transformers import PreTrainedTokenizerFast, BartForConditionalGeneration

# KoBART 요약 모델 로드 (성능 개선된 digit82/kobart-summarization 사용)
tokenizer = PreTrainedTokenizerFast.from_pretrained("digit82/kobart-summarization")
model = BartForConditionalGeneration.from_pretrained("digit82/kobart-summarization")

# 배우 정보 API URL (1~10번 배우)
actor_ids = range(1, 11)
base_url = "http://52.78.226.136:4000/actor/{}"

# 최종 정리된 텍스트 저장 리스트
actor_texts = []

def summarize_text(text):
    """KoBART 모델을 이용해 텍스트 요약"""
    text = text.replace("\n", " ")  # 줄바꿈 제거
    raw_input_ids = tokenizer.encode(text, truncation=True, max_length=512)
    input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

    summary_ids = model.generate(
        torch.tensor([input_ids]),
        num_beams=4,
        max_length=512,  # 요약문의 최대 길이
        eos_token_id=1  # 종료 토큰
    )

    return tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)

for actor_id in actor_ids:
    try:
        response = requests.get(base_url.format(actor_id))

        if response.status_code == 200:
            data = response.json()

            if data.get("success") and "data" in data:
                actor = data["data"]
                profile = actor.get("actorProfile", {})
                details = actor.get("actorDetails", {})

                # 📌 메인 정보 (단순 문자열 합치기)
                main_info = f"{profile.get('nameKo', 'N/A')}, {profile.get('age', 'N/A')}세, {profile.get('height', 'N/A')}cm, {profile.get('weight', 'N/A')}kg, {'남성' if profile.get('gender') == 'male' else '여성'}"

                # 📌 부가 정보 (요약 모델 사용)
                extra_text = f"경력: {details.get('career', 'N/A')}. 특기: {details.get('specialSkills', 'N/A')}. 자기소개: {details.get('bio', 'N/A')}"
                summary = summarize_text(extra_text)

                # 최종 KoCLIP 입력 포맷
                actor_texts.append(f"메인 정보: {main_info}. 부가 정보: {summary}")

            else:
                actor_texts.append(f"배우 {actor_id}: 정보 없음")

        else:
            actor_texts.append(f"배우 {actor_id}: API 요청 실패 (상태 코드 {response.status_code})")

    except requests.exceptions.RequestException as e:
        actor_texts.append(f"배우 {actor_id}: 요청 중 오류 발생 - {e}")

# 결과 출력
for text in actor_texts:
    print(text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/295 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/682k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/109 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels will be overwritten to 2.
# pytorch_model.bin:   0%|          | 0.00/496M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# 메인 정보: 김다빈, 27세, 179cm, 72kg, 남성. 부가 정보: 특기: 야구, 수영(자유형). 야구, 수영(자유형). 자기소개: 맡겨 주신다면 좋은 연기 보여드리겠습니다! 감사합니다!
# 메인 정보: 전민서, 23세, 179cm, 64kg, 남성. 부가 정보: 특기: 볼링, 골프, 수영, 그림, 복싱. 자기소개: 잘 부탁드립니다!
# 메인 정보: 송마루, 21세, 178cm, 63kg, 남성. 부가 정보: 경기대학교 연기학과에 재학중이며 경기대학교 연기학과에 재학중입니다 !!! 현장 경험이 아직 많이 없는건 사실입니다 !!! 하지만 어떤 환경에서든 빨리적응하고 제가 하는 분야나 일에 있어서 책임감 있는 사람이기에 믿고 맡겨주시면 함께 좋은 작품 만들어나가보고 싶습니다!!!
# 메인 정보: 김제국, 24세, 171cm, 65kg, 남성. 부가 정보: 2017~19년 고등학교 연극부에 들어가 연기에 재미를 느끼며 관심있게 배우지망하는 김제국씨는 대학교를 레크레에이션학과를 재학 했지만 연기에 꿈을 접을 수 없어 24년 9월 연기를 다시 시작하게 되었다.
# 메인 정보: 박성훈, 25세, 177cm, 65kg, 남성. 부가 정보: 자기소개: 연기와 모델일 이제 배우기 시작했습니다! 기회가 있으면 열심히 해보고 싶습니다!
# 메인 정보: 임건표, 31세, 177cm, 130kg, 남성. 부가 정보: 임건표 입니다.
# 메인 정보: 김민서, 23세, 175cm, 61kg, 남성. 부가 정보: 경력: 경력이 없습니다 경험 해보고싶어 올려봅니다
# 메인 정보: 이윤선, 29세, 177cm, 68kg, 남성. 부가 정보: 2024 용감한 형사들 -강남막내형사역 2023 대만 예능 the hungergame -김해편출연 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역                                                                                                                        집으로가는 길 -군인역(주연) 2022 에너제틱 -김민우역(조연)                              뮤지컬 너와나 이곳에 우리 – 정국                       뮤지컬 너와나 이곳에 우리 – 정국                                                                                                                                          용감한 형사들 -강남막내형사역 2023 대만 예능 the hungergame -김해편출연 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역
# 메인 정보: 리아즈  / Riaz(외국인, 외국), 33세, 169cm, 68kg, 남성. 부가 정보: -- TV 시리즈 2024 - 서프라이즈(MBC) - 영화 감독 역 & 인도 남자 역 - - 영화 이름- 슬픈 열대  (2025년 출시 예정) -- 모델 2015 - 샨토마리암 대학교 행사 - 모델. 특기: 연기, 모델링, 댄스, 스포츠(축구, 크리켓, 배드민턴, 두뇌 게임 ), 요리. 자기소개: Contact me for more details.
# 메인 정보: 오혁, 15세, 165cm, 49kg, 남성. 부가 정보: 자룡이친구역 단편영화 고무나무 주인공아역 자룡이친구역 단편영화 고무나무 주인공아역 엉클 열매반아이 아가미 애니메이션 강하 커넥트 미소년역 효심이네 각자도생 어린효준 전천당 건아역.

# %% [markdown]
# * 기본값(Default)으로 "미상"이라는 문자열이 들어가도록 설정

# %%
# 배우 정보 API URL (1~10번 배우)
actor_ids = range(1, 11)
base_url = "http://52.78.226.136:4000/actor/{}"

# 최종 정리된 텍스트 저장 리스트
actor_texts = []

def summarize_text(text):
    """KoBART 모델을 이용해 텍스트 요약"""
    text = text.replace("\n", " ")  # 줄바꿈 제거
    raw_input_ids = tokenizer.encode(text, truncation=True, max_length=512)
    input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

    summary_ids = model.generate(
        torch.tensor([input_ids]),
        num_beams=4,
        max_length=512,  # 요약문의 최대 길이
        eos_token_id=1  # 종료 토큰
    )

    return tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)

for actor_id in actor_ids:
    try:
        response = requests.get(base_url.format(actor_id))

        if response.status_code == 200:
            data = response.json()

            if data.get("success") and "data" in data:
                actor = data["data"]
                profile = actor.get("actorProfile", {})
                details = actor.get("actorDetails", {})

                # 📌 메인 정보 (자연스러운 문장으로 개선)
                name = profile.get('nameKo', '이름 없음')
                gender = "남성" if profile.get('gender') == 'male' else "여성"
                age = profile.get('age', '미상')
                height = profile.get('height', '미상')
                weight = profile.get('weight', '미상')

                main_info = f"배우 {name}, 성별: {gender}, 나이: {age}, 키: {height}cm, 몸무게: {weight}kg"

                # 📌 부가 정보 (요약 모델 사용)
                extra_text = f"경력: {details.get('career', '정보 없음')}. 특기: {details.get('specialSkills', '정보 없음')}. 자기소개: {details.get('bio', '정보 없음')}"
                summary = summarize_text(extra_text)

                # 최종 KoCLIP 입력 포맷
                actor_texts.append(f"메인 정보: {main_info}. 부가 정보: {summary}")

            else:
                actor_texts.append(f"배우 {actor_id}: 정보 없음")

        else:
            actor_texts.append(f"배우 {actor_id}: API 요청 실패 (상태 코드 {response.status_code})")

    except requests.exceptions.RequestException as e:
        actor_texts.append(f"배우 {actor_id}: 요청 중 오류 발생 - {e}")

# 결과 출력
for text in actor_texts:
    print(text)
# Out:
# 메인 정보: 배우 김다빈, 성별: 남성, 나이: 27, 키: 179cm, 몸무게: 72kg. 부가 정보: 특기: 야구, 수영(자유형). 야구, 수영(자유형). 자기소개: 맡겨 주신다면 좋은 연기 보여드리겠습니다! 감사합니다!
# 메인 정보: 배우 전민서, 성별: 남성, 나이: 23, 키: 179cm, 몸무게: 64kg. 부가 정보: 특기: 볼링, 골프, 수영, 그림, 복싱. 자기소개: 잘 부탁드립니다!
# 메인 정보: 배우 송마루, 성별: 남성, 나이: 21, 키: 178cm, 몸무게: 63kg. 부가 정보: 경기대학교 연기학과에 재학중이며 경기대학교 연기학과에 재학중입니다 !!! 현장 경험이 아직 많이 없는건 사실입니다 !!! 하지만 어떤 환경에서든 빨리적응하고 제가 하는 분야나 일에 있어서 책임감 있는 사람이기에 믿고 맡겨주시면 함께 좋은 작품 만들어나가보고 싶습니다!!!
# 메인 정보: 배우 김제국, 성별: 남성, 나이: 24, 키: 171cm, 몸무게: 65kg. 부가 정보: 2017~19년 고등학교 연극부에 들어가 연기에 재미를 느끼며 관심있게 배우지망하는 김제국씨는 대학교를 레크레에이션학과를 재학 했지만 연기에 꿈을 접을 수 없어 24년 9월 연기를 다시 시작하게 되었다.
# 메인 정보: 배우 박성훈, 성별: 남성, 나이: 25, 키: 177cm, 몸무게: 65kg. 부가 정보: 자기소개: 연기와 모델일 이제 배우기 시작했습니다! 기회가 있으면 열심히 해보고 싶습니다!
# 메인 정보: 배우 임건표, 성별: 남성, 나이: 31, 키: 177cm, 몸무게: 130kg. 부가 정보: 임건표 입니다.
# 메인 정보: 배우 김민서, 성별: 남성, 나이: 23, 키: 175cm, 몸무게: 61kg. 부가 정보: 경력: 경력이 없습니다 경험 해보고싶어 올려봅니다
# 메인 정보: 배우 이윤선, 성별: 남성, 나이: 29, 키: 177cm, 몸무게: 68kg. 부가 정보: 2024 용감한 형사들 -강남막내형사역 2023 대만 예능 the hungergame -김해편출연 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역                                                                                                                        집으로가는 길 -군인역(주연) 2022 에너제틱 -김민우역(조연)                              뮤지컬 너와나 이곳에 우리 – 정국                       뮤지컬 너와나 이곳에 우리 – 정국                                                                                                                                          용감한 형사들 -강남막내형사역 2023 대만 예능 the hungergame -김해편출연 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역
# 메인 정보: 배우 리아즈  / Riaz(외국인, 외국), 성별: 남성, 나이: 33, 키: 169cm, 몸무게: 68kg. 부가 정보: -- TV 시리즈 2024 - 서프라이즈(MBC) - 영화 감독 역 & 인도 남자 역 - - 영화 이름- 슬픈 열대  (2025년 출시 예정) -- 모델 2015 - 샨토마리암 대학교 행사 - 모델. 특기: 연기, 모델링, 댄스, 스포츠(축구, 크리켓, 배드민턴, 두뇌 게임 ), 요리. 자기소개: Contact me for more details.
# 메인 정보: 배우 오혁, 성별: 남성, 나이: 15, 키: 165cm, 몸무게: 49kg. 부가 정보: 자룡이친구역 단편영화 고무나무 주인공아역 자룡이친구역 단편영화 고무나무 주인공아역 엉클 열매반아이 아가미 애니메이션 강하 커넥트 미소년역 효심이네 각자도생 어린효준 전천당 건아역.

# %% [markdown]
# * KoCLIP의 입력으로 들어가기 위해 최대 길이 50으로 제한
# * 원본 문자열과 요약 문자열을 함께 출력

# %%
# 배우 정보 API URL (1~10번 배우)
actor_ids = range(1, 11)
base_url = "http://52.78.226.136:4000/actor/{}"

# 최종 정리된 텍스트 저장 리스트
actor_texts = []

def summarize_text(text):
    """KoBART 모델을 이용해 텍스트 요약 (KoCLIP에 맞게 50자 제한)"""
    text = text.replace("\n", " ")  # 줄바꿈 제거
    raw_input_ids = tokenizer.encode(text, truncation=True, max_length=512)
    input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

    summary_ids = model.generate(
        torch.tensor([input_ids]),
        num_beams=4,
        max_length=50,  # KoCLIP 제한에 맞춰 50자로 요약
        eos_token_id=1  # 종료 토큰
    )

    return tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)

for actor_id in actor_ids:
    try:
        response = requests.get(base_url.format(actor_id))

        if response.status_code == 200:
            data = response.json()

            if data.get("success") and "data" in data:
                actor = data["data"]
                profile = actor.get("actorProfile", {})
                details = actor.get("actorDetails", {})

                # 📌 메인 정보 (자연스러운 문장으로 개선)
                name = profile.get('nameKo', '이름 없음')
                gender = "남성" if profile.get('gender') == 'male' else "여성"
                age = profile.get('age', '미상')
                height = profile.get('height', '미상')
                weight = profile.get('weight', '미상')

                main_info = f"배우 {name}, 성별: {gender}, 나이: {age}, 키: {height}cm, 몸무게: {weight}kg"

                # 📌 부가 정보 (요약 모델 사용)
                extra_text = f"경력: {details.get('career', '정보 없음')}. 특기: {details.get('specialSkills', '정보 없음')}. 자기소개: {details.get('bio', '정보 없음')}"
                summary = summarize_text(extra_text)

                # 최종 KoCLIP 입력 포맷
                actor_texts.append(f"메인 정보: {main_info}. 부가 정보: {summary}")

                # 📌 콘솔 출력 (요약 전후 비교)
                print("=" * 80)
                print(f"🎭 배우 {name} (ID: {actor_id})")
                print(f"📌 원본 부가 정보:\n{extra_text}\n")
                print(f"📌 요약된 부가 정보 (KoCLIP 입력):\n{summary}")
                print("=" * 80 + "\n")

            else:
                actor_texts.append(f"배우 {actor_id}: 정보 없음")

        else:
            actor_texts.append(f"배우 {actor_id}: API 요청 실패 (상태 코드 {response.status_code})")

    except requests.exceptions.RequestException as e:
        actor_texts.append(f"배우 {actor_id}: 요청 중 오류 발생 - {e}")

# 최종 결과 출력
for text in actor_texts:
    print(text)
# Out:
# ================================================================================
# 🎭 배우 김다빈 (ID: 1)
# 📌 원본 부가 정보:
# 경력: 단편 영화 '마중 가는 길' 권민준 역 - 주연
# 단편 영화 '열아홉' 백민준 역-주연
# 단편 영화'사라졌다 한들 떠오르는 것' 명수 역-주연
# 단편영화'신호' 도영 역-주연. 특기: 야구, 수영(자유형). 자기소개: 맡겨 주신다면 좋은 연기 보여드리겠습니다!
# 감사합니다!
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 특기: 야구, 수영(자유형). 야구, 수영(자유형). 자기소개: 맡겨 주신다면 좋은 연기 보여드리겠습니다! 감사합니다!
# ================================================================================
#
# ================================================================================
# 🎭 배우 전민서 (ID: 2)
# 📌 원본 부가 정보:
# 경력: 프로필에 첨부되어있습니다!. 특기: 볼링, 골프, 수영, 그림, 복싱. 자기소개: 잘 부탁드립니다!
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 특기: 볼링, 골프, 수영, 그림, 복싱. 자기소개: 잘 부탁드립니다!
# ================================================================================
#
# ================================================================================
# 🎭 배우 송마루 (ID: 3)
# 📌 원본 부가 정보:
# 경력: 연극
# 우리읍내- 무대감독
# 아름다운 사인 - 남자
#
# 음악극 뮤지컬
#
# 단편 영화
# 교내 단편영화 - (주연). 특기: 현대무용 아크로바틱 테크닉 약간의 개인기. 자기소개: 현재 경기대학교 연기학과에 재학중입니다
#
# 현장 경험이 아직 많이 없는건 사실입니다 !!!
# 하지만 어떤 환경에서든 빨리적응하고
# 제가 하는 분야나 일에 있어서 책임감 있는 사람이기에 믿고 맡겨주시면 함께 좋은 작품 만들어나가보고 싶습니다
# 저는 준비됐습니다!!
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 경기대학교 연기학과에 재학중이며 경기대학교 연기학과에 재학중이고 어떤 환경에서든 빨리적응하고 제가 하는 분야나 일에 있어서 책임감 있는 사람이기에 믿고 맡겨주시면 함께 좋은 작품 만들어나가보고
# ================================================================================
#
# ================================================================================
# 🎭 배우 김제국 (ID: 4)
# 📌 원본 부가 정보:
# 경력: . 특기: 짜증내는연기와, 바보연기, 능청스러운 연기 자신 있습니다. 말을 조리있게 잘합니다. 카메라를 부끄러워히지 않고 좋아합니다. 자기소개: 안녕하세요 배우지망하는 김제국입니다.
# 2017~19년 고등학교 연극부에 들어가 연기에 재미를 느끼며 관심있게 되었습니다.
# 대학교를 레크레에이션학과를 재학 했지만 연기에 꿈을 접을 수 없어, 24년 9월 연기를 다시 시작하게 되었습니다.
# 아직까지 경력은 없습니다. 하지만 자신감이 넘칩니다. 잘할 수 있으며 꿈이 큰 학생입니다.
# 기회가 된다면 잡고싶습니다. 많은 관심부탁드리며 긴 글 읽어주셔서 감사합니다. 열심히 잘하겠습니다
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 2017~19년 고등학교 연극부에 들어가 연기에 재미를 느끼며 관심있게 배우지망하는 김제국씨는 대학교를 레크레에이션학과를 재학 했지만 연기에 꿈을 접을 수 없어 24년 9월 연기를 다시 시작하게
# ================================================================================
#
# ================================================================================
# 🎭 배우 박성훈 (ID: 5)
# 📌 원본 부가 정보:
# 경력: . 특기: 사투리 가능합니다. 자기소개: 연기와 모델일 이제 배우기 시작했습니다!
# 기회가 있으면 열심히 해보고 싶습니다 잘 부탁 드립니다!
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 자기소개: 연기와 모델일 이제 배우기 시작했습니다! 기회가 있으면 열심히 해보고 싶습니다!
# ================================================================================
#
# ================================================================================
# 🎭 배우 임건표 (ID: 6)
# 📌 원본 부가 정보:
# 경력: 길들여진새 - 멀티역. 특기: 보컬, 오토바이운전. 자기소개: 안녕하세요 신인배우 임건표 입니다.
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 임건표 입니다.
# ================================================================================
#
# ================================================================================
# 🎭 배우 김민서 (ID: 7)
# 📌 원본 부가 정보:
# 경력: 경력이 없습니다. 특기: . 자기소개: 경력은 없습니다 경험 해보고싶어 올려봅니다
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 경력: 경력이 없습니다 경험 해보고싶어 올려봅니다
# ================================================================================
#
# ================================================================================
# 🎭 배우 이윤선 (ID: 8)
# 📌 원본 부가 정보:
# 경력: CAREER
#
# ▶단편영화
# 2024 42.9 -조효준역(주연)
#        집으로가는 길 -군인역(주연)
# 2022 에너제틱 -김민우역(조연)
#        목소리꽃 -유연준역(조연)
# ▶영상
# 2024 용감한 형사들 -남자친구역
#        용감한 형사들 -강남막내형사역
# 2023 대만 예능 the hungergame -김해편출연
# 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역
# ▶무대
# 2024 푸에르타부르자 팀 - vaterfly
#        넌버벌 아트퍼포먼스 페인터즈
# 2022 사춘기메들리-영복
#        뮤지컬baking-꾸꾸
#        뮤지컬 너와나 이곳에 우리 – 정국. 특기: 그림, 춤. 자기소개: CAREER
# ▶단편영화
# 2024 42.9 -조효준역(주연)
#        집으로가는 길 -군인역(주연)
# 2022 에너제틱 -김민우역(조연)
#        목소리꽃 -유연준역(조연)
# ▶영상
# 2024 용감한 형사들 -남자친구역
#        용감한 형사들 -강남막내형사역
# 2023 대만 예능 the hungergame -김해편출연
# 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역
# ▶무대
# 2024 푸에르타부르자 팀 - vaterfly
#        넌버벌 아트퍼포먼스 페인터즈
# 2022 사춘기메들리-영복
#        뮤지컬baking-꾸꾸
#        뮤지컬 너와나 이곳에 우리 – 정국
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 용감한 형사들 -강남막내형사역 2023 대만 예능 the hungergame -김해편출연 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역
# ================================================================================
#
# ================================================================================
# 🎭 배우 리아즈  / Riaz(외국인, 외국) (ID: 9)
# 📌 원본 부가 정보:
# 경력: -- TV 시리즈
# 2024 - 서프라이즈(MBC) - 영화 감독 역 & 인도 남자 역
# - - 영화 이름-  슬픈 열대  (2025년 출시 예정)
# -- 모델
# 2015 - 샨토마리암 대학교 행사 - 모델. 특기: 연기, 모델링, 댄스, 스포츠(축구, 크리켓, 배드민턴, 두뇌 게임 ), 요리. 자기소개: Contact me for more details.
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# TV 시리즈 2024 - 서프라이즈(MBC) - 영화 감독 역 & 인도 남자 역 - - 영화 이름- 슬픈 열대  (2025년 출시 예정) -- 모델 2015 - 샨토마리암 대학교 행사 -
# ================================================================================
#
# ================================================================================
# 🎭 배우 오혁 (ID: 10)
# 📌 원본 부가 정보:
# 경력: <광고>
# 티아이얼짱대상
# 호미들 힙합 뮤직비디오
# 베트맨버스터 CF
# 키자니아 CF  PD역할
# 키자니아 제주도 CF
# 보건복지부 영상
# 미에로화이바 스파클링
#
# <모델>
# 지애담 중등교재
# 랩스주니어
# 카카오프렌즈
# 우등생논술 1월호
# 지애담 중등교재
#
# <피팅모델 >
# 인디고뱅크키즈 피팅모델
# 티몬 이랜드 펠릭스 피팅모델
# 이라인 피팅모델
# 소유 아동복 피팅모델
# 투키즈 피팅모델
#
# ​ <드라마>
# 출사표 자룡이친구역
# 단편영화 고무나무 주인공아역
# 엉클 열매반아이
# 아가미 애니메이션 강하
# 커넥트 미소년역
# 효심이네 각자도생 어린효준
# 전천당 건아역. 특기: 기타연주 아크로바틱 수영 주짓수 복싱. 자기소개: 안녕하세요
# 연기에 진심인 만큼
# 최선을 다하는 오혁입니다
# 잘 부탁드립니다
#
# 📌 요약된 부가 정보 (KoCLIP 입력):
# 자룡이친구역 단편영화 고무나무 주인공아역 자룡이친구역 단편영화 고무나무 주인공아역 엉클 열매반아이 아가미 애니메이션 강하 커넥트 미소년역 효심이네 각자도생 어린
# ================================================================================
#
# 메인 정보: 배우 김다빈, 성별: 남성, 나이: 27, 키: 179cm, 몸무게: 72kg. 부가 정보: 특기: 야구, 수영(자유형). 야구, 수영(자유형). 자기소개: 맡겨 주신다면 좋은 연기 보여드리겠습니다! 감사합니다!
# 메인 정보: 배우 전민서, 성별: 남성, 나이: 23, 키: 179cm, 몸무게: 64kg. 부가 정보: 특기: 볼링, 골프, 수영, 그림, 복싱. 자기소개: 잘 부탁드립니다!
# 메인 정보: 배우 송마루, 성별: 남성, 나이: 21, 키: 178cm, 몸무게: 63kg. 부가 정보: 경기대학교 연기학과에 재학중이며 경기대학교 연기학과에 재학중이고 어떤 환경에서든 빨리적응하고 제가 하는 분야나 일에 있어서 책임감 있는 사람이기에 믿고 맡겨주시면 함께 좋은 작품 만들어나가보고
# 메인 정보: 배우 김제국, 성별: 남성, 나이: 24, 키: 171cm, 몸무게: 65kg. 부가 정보: 2017~19년 고등학교 연극부에 들어가 연기에 재미를 느끼며 관심있게 배우지망하는 김제국씨는 대학교를 레크레에이션학과를 재학 했지만 연기에 꿈을 접을 수 없어 24년 9월 연기를 다시 시작하게
# 메인 정보: 배우 박성훈, 성별: 남성, 나이: 25, 키: 177cm, 몸무게: 65kg. 부가 정보: 자기소개: 연기와 모델일 이제 배우기 시작했습니다! 기회가 있으면 열심히 해보고 싶습니다!
# 메인 정보: 배우 임건표, 성별: 남성, 나이: 31, 키: 177cm, 몸무게: 130kg. 부가 정보: 임건표 입니다.
# 메인 정보: 배우 김민서, 성별: 남성, 나이: 23, 키: 175cm, 몸무게: 61kg. 부가 정보: 경력: 경력이 없습니다 경험 해보고싶어 올려봅니다
# 메인 정보: 배우 이윤선, 성별: 남성, 나이: 29, 키: 177cm, 몸무게: 68kg. 부가 정보: 용감한 형사들 -강남막내형사역 2023 대만 예능 the hungergame -김해편출연 2017 대전경찰청 보이스피싱방지 홍보영상 납득이역
# 메인 정보: 배우 리아즈  / Riaz(외국인, 외국), 성별: 남성, 나이: 33, 키: 169cm, 몸무게: 68kg. 부가 정보: TV 시리즈 2024 - 서프라이즈(MBC) - 영화 감독 역 & 인도 남자 역 - - 영화 이름- 슬픈 열대  (2025년 출시 예정) -- 모델 2015 - 샨토마리암 대학교 행사 -
# 메인 정보: 배우 오혁, 성별: 남성, 나이: 15, 키: 165cm, 몸무게: 49kg. 부가 정보: 자룡이친구역 단편영화 고무나무 주인공아역 자룡이친구역 단편영화 고무나무 주인공아역 엉클 열매반아이 아가미 애니메이션 강하 커넥트 미소년역 효심이네 각자도생 어린

# %% [markdown]
# #### <b>KoCLIP</b> 모델을 활용한 특징 벡터 추출

# %%
import requests
import torch
import pandas as pd
from transformers import AutoModel, AutoProcessor

# KoCLIP 모델 로드
repo = "Bingsu/clip-vit-large-patch14-ko"
model = AutoModel.from_pretrained(repo)
processor = AutoProcessor.from_pretrained(repo)

# 배우 정보 API URL (1~10번 배우)
actor_ids = range(1, 11)
base_url = "http://52.78.226.136:4000/actor/{}"

# 최종 데이터 저장 리스트
actor_data = []

for actor_id in actor_ids:
    try:
        response = requests.get(base_url.format(actor_id))

        if response.status_code == 200:
            data = response.json()

            if data.get("success") and "data" in data:
                actor = data["data"]
                profile = actor.get("actorProfile", {})

                # 📌 메인 정보 생성
                name = profile.get('nameKo', '이름 없음')
                gender = "남성" if profile.get('gender') == 'male' else "여성"
                age = profile.get('age', '미상')
                height = profile.get('height', '미상')
                weight = profile.get('weight', '미상')

                main_info = f"배우 {name}, 성별: {gender}, 나이: {age}, 키: {height}cm, 몸무게: {weight}kg"

                # 📌 KoCLIP 모델을 사용해 텍스트 특징 벡터 추출
                inputs = processor(text=[main_info], return_tensors="pt", padding=True)
                with torch.inference_mode():
                    outputs = model.get_text_features(**inputs)

                text_feature_vector = outputs.squeeze().tolist()  # 512차원 벡터 변환

                # 데이터 저장
                actor_data.append([actor_id, name, text_feature_vector])

                # 📌 콘솔 출력
                print("=" * 80)
                print(f"🎭 배우 {name} (ID: {actor_id})")
                print(f"📌 메인 정보: {main_info}")
                print(f"📌 특징 벡터 (512차원) 샘플: {text_feature_vector[:5]} ...")  # 일부만 출력
                print("=" * 80 + "\n")

            else:
                print(f"배우 {actor_id}: API 응답에 데이터 없음")

        else:
            print(f"배우 {actor_id}: API 요청 실패 (상태 코드 {response.status_code})")

    except requests.exceptions.RequestException as e:
        print(f"배우 {actor_id}: 요청 중 오류 발생 - {e}")

# 📌 CSV 저장 (배우 ID, 이름, 512차원 벡터)
df = pd.DataFrame(actor_data, columns=["actor_id", "name", "text_feature_vector"])
df.to_csv("actor_text_features.csv", index=False)
print("✅ CSV 저장 완료: actor_text_features.csv")
# Out:
# config.json:   0%|          | 0.00/4.88k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/380 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.21M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/870k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# ================================================================================
# 🎭 배우 김다빈 (ID: 1)
# 📌 메인 정보: 배우 김다빈, 성별: 남성, 나이: 27, 키: 179cm, 몸무게: 72kg
# 📌 특징 벡터 (512차원) 샘플: [-0.21834401786327362, 0.48850345611572266, -0.013849967159330845, 0.36802199482917786, -0.002494649961590767] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 전민서 (ID: 2)
# 📌 메인 정보: 배우 전민서, 성별: 남성, 나이: 23, 키: 179cm, 몸무게: 64kg
# 📌 특징 벡터 (512차원) 샘플: [-0.09093993902206421, 0.46251633763313293, -0.03016846999526024, 0.4572383165359497, 0.14056777954101562] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 송마루 (ID: 3)
# 📌 메인 정보: 배우 송마루, 성별: 남성, 나이: 21, 키: 178cm, 몸무게: 63kg
# 📌 특징 벡터 (512차원) 샘플: [-0.10209973901510239, 0.5782990455627441, 0.006505932658910751, 0.45003741979599, -0.12687629461288452] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 김제국 (ID: 4)
# 📌 메인 정보: 배우 김제국, 성별: 남성, 나이: 24, 키: 171cm, 몸무게: 65kg
# 📌 특징 벡터 (512차원) 샘플: [-0.31821179389953613, 0.5695582032203674, -0.12693315744400024, 0.5020290613174438, -0.15686330199241638] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 박성훈 (ID: 5)
# 📌 메인 정보: 배우 박성훈, 성별: 남성, 나이: 25, 키: 177cm, 몸무게: 65kg
# 📌 특징 벡터 (512차원) 샘플: [-0.15888544917106628, 0.5937153697013855, -0.09322254359722137, 0.5083370208740234, -0.2836582362651825] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 임건표 (ID: 6)
# 📌 메인 정보: 배우 임건표, 성별: 남성, 나이: 31, 키: 177cm, 몸무게: 130kg
# 📌 특징 벡터 (512차원) 샘플: [-0.28093087673187256, 0.48552563786506653, 0.45241090655326843, 0.46006882190704346, -0.35206839442253113] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 김민서 (ID: 7)
# 📌 메인 정보: 배우 김민서, 성별: 남성, 나이: 23, 키: 175cm, 몸무게: 61kg
# 📌 특징 벡터 (512차원) 샘플: [-0.11889830231666565, 0.5500685572624207, 0.01871749386191368, 0.36583563685417175, -0.062203191220760345] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 이윤선 (ID: 8)
# 📌 메인 정보: 배우 이윤선, 성별: 남성, 나이: 29, 키: 177cm, 몸무게: 68kg
# 📌 특징 벡터 (512차원) 샘플: [0.07843537628650665, 0.3988845944404602, 0.013370517641305923, 0.309501051902771, -0.2535199820995331] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 리아즈  / Riaz(외국인, 외국) (ID: 9)
# 📌 메인 정보: 배우 리아즈  / Riaz(외국인, 외국), 성별: 남성, 나이: 33, 키: 169cm, 몸무게: 68kg
# 📌 특징 벡터 (512차원) 샘플: [-0.44073542952537537, 0.6599945425987244, 0.16844221949577332, 0.30607739090919495, -0.192023366689682] ...
# ================================================================================
#
# ================================================================================
# 🎭 배우 오혁 (ID: 10)
# 📌 메인 정보: 배우 오혁, 성별: 남성, 나이: 15, 키: 165cm, 몸무게: 49kg
# 📌 특징 벡터 (512차원) 샘플: [-0.16152463853359222, 0.44045785069465637, 0.17742161452770233, 0.6585274338722229, -0.3261238932609558] ...
# ================================================================================
#
# ✅ CSV 저장 완료: actor_text_features.csv

# %%
import torch
import pandas as pd
import requests
from transformers import AutoModel, AutoProcessor

# KoCLIP 모델 불러오기
repo = "Bingsu/clip-vit-large-patch14-ko"
model = AutoModel.from_pretrained(repo)
processor = AutoProcessor.from_pretrained(repo)

BATCH_SIZE = 32  # 배치 크기
TOTAL_ACTORS = 500  # 총 배우 수
FEATURE_DIM = 768  # KoCLIP 벡터 차원 (768여야 정상)

def extract_text_features(texts, actor_ids):
    """KoCLIP을 활용하여 텍스트 특징 벡터 추출"""
    inputs = processor(text=texts, return_tensors="pt", padding=True)

    with torch.inference_mode():
        outputs = model.get_text_features(**inputs)

    features = outputs.cpu().tolist()

    # 벡터 차원 검증
    for i, feature in enumerate(features):
        if len(feature) != FEATURE_DIM:
            print(f"🚨 [경고] 배우 {actor_ids[i]}: 벡터 크기 불일치 ({len(feature)}차원). 자동 수정")
            features[i] = feature[:FEATURE_DIM] + [0.0] * (FEATURE_DIM - len(feature))  # 768차원 맞춤

    return features

data = []
batch_texts = []
batch_actor_ids = []

for idx, actor_id in enumerate(range(1, TOTAL_ACTORS + 1), start=1):
    url = f"http://52.78.226.136:4000/actor/{actor_id}"
    response = requests.get(url)

    if response.status_code != 200:
        print(f"⚠️ [실패] 배우 {actor_id}: 서버 응답 실패 (HTTP {response.status_code})")
        continue  # 요청 실패 시 건너뜀

    actor_data = response.json().get("data", {})
    profile = actor_data.get("actorProfile", {})

    # 메인 정보 생성
    main_info = f"배우 {profile.get('nameKo', '알 수 없음')}, 성별: {profile.get('gender', '미상')}, 나이: {profile.get('age', '미상')}, 키: {profile.get('height', '미상')}cm, 몸무게: {profile.get('weight', '미상')}kg"

    batch_texts.append(main_info)
    batch_actor_ids.append(actor_id)

    # 현재 배우 처리 완료 로그
    print(f"✅ [완료] 배우 {actor_id}: '{main_info}' 처리됨")

    # 배치 크기만큼 쌓이면 KoCLIP 추론
    if len(batch_texts) == BATCH_SIZE:
        print(f"🔄 [배치 처리] {BATCH_SIZE}명 특징 벡터 추출 중...")
        feature_vectors = extract_text_features(batch_texts, batch_actor_ids)

        for i in range(BATCH_SIZE):
            data.append([batch_actor_ids[i], batch_texts[i]] + feature_vectors[i])

        # 현재 배치 벡터 크기 확인
        print(f"📌 [벡터 크기 확인] KoCLIP 벡터 차원: {len(feature_vectors[0])} (정상: {FEATURE_DIM})")

        batch_texts = []
        batch_actor_ids = []

# 남은 데이터 처리
if batch_texts:
    print(f"🔄 [배치 처리] 남은 {len(batch_texts)}명 처리 중...")
    feature_vectors = extract_text_features(batch_texts, batch_actor_ids)
    for i in range(len(batch_texts)):
        data.append([batch_actor_ids[i], batch_texts[i]] + feature_vectors[i])

    print(f"📌 [벡터 크기 확인] KoCLIP 벡터 차원: {len(feature_vectors[0])} (정상: {FEATURE_DIM})")

# CSV 저장
columns = ["actor_id", "main_info"] + [f"feature_{i}" for i in range(FEATURE_DIM)]
df = pd.DataFrame(data, columns=columns)
df.to_csv("actor_features.csv", index=False)

print("\n✅ 배우 500명의 특징 벡터가 CSV에 저장되었습니다.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.88k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/380 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.21M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/870k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# ✅ [완료] 배우 1: '배우 김다빈, 성별: male, 나이: 27, 키: 179cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 2: '배우 전민서, 성별: male, 나이: 23, 키: 179cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 3: '배우 송마루, 성별: male, 나이: 21, 키: 178cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 4: '배우 김제국, 성별: male, 나이: 24, 키: 171cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 5: '배우 박성훈, 성별: male, 나이: 25, 키: 177cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 6: '배우 임건표, 성별: male, 나이: 31, 키: 177cm, 몸무게: 130kg' 처리됨
# ✅ [완료] 배우 7: '배우 김민서, 성별: male, 나이: 23, 키: 175cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 8: '배우 이윤선, 성별: male, 나이: 29, 키: 177cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 9: '배우 리아즈  / Riaz(외국인, 외국), 성별: male, 나이: 33, 키: 169cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 10: '배우 오혁, 성별: male, 나이: 15, 키: 165cm, 몸무게: 49kg' 처리됨
# ✅ [완료] 배우 11: '배우 황찬울, 성별: male, 나이: 23, 키: 181cm, 몸무게: 66kg' 처리됨
# ✅ [완료] 배우 12: '배우 오재준, 성별: male, 나이: 29, 키: 183cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 13: '배우 최영진, 성별: male, 나이: 21, 키: 180cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 14: '배우 이석우, 성별: male, 나이: 29, 키: 179cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 15: '배우 이준행, 성별: male, 나이: 28, 키: 173cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 16: '배우 이서, 성별: male, 나이: 28, 키: 185cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 17: '배우 문석호, 성별: male, 나이: 31, 키: 182cm, 몸무게: 76kg' 처리됨
# ✅ [완료] 배우 18: '배우 이동현, 성별: male, 나이: 24, 키: 178cm, 몸무게: 52kg' 처리됨
# ✅ [완료] 배우 19: '배우 최수헌, 성별: male, 나이: 21, 키: 170cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 20: '배우 최성묵, 성별: male, 나이: 29, 키: 174cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 21: '배우 박준영, 성별: male, 나이: 39, 키: 170cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 22: '배우 권대임, 성별: male, 나이: 32, 키: 172cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 23: '배우 알라베르디 (남자 외국인 모델), 성별: male, 나이: 31, 키: 180cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 24: '배우 신주원, 성별: male, 나이: 25, 키: 166cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 25: '배우 김종호, 성별: male, 나이: 24, 키: 175cm, 몸무게: 58kg' 처리됨
# ✅ [완료] 배우 26: '배우 이일랑, 성별: male, 나이: 33, 키: 172cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 27: '배우 권태모, 성별: male, 나이: 40, 키: 170cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 28: '배우 이재명, 성별: male, 나이: 46, 키: 178cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 29: '배우 김준성, 성별: male, 나이: 30, 키: 180cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 30: '배우 전정근, 성별: male, 나이: 31, 키: 177cm, 몸무게: 56kg' 처리됨
# ✅ [완료] 배우 31: '배우 배승한, 성별: male, 나이: 27, 키: 175cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 32: '배우 김준기, 성별: male, 나이: 19, 키: 176cm, 몸무게: 65kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 33: '배우 강한성, 성별: male, 나이: 20, 키: 179cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 34: '배우 김윤성, 성별: male, 나이: 12, 키: 158cm, 몸무게: 57kg' 처리됨
# ✅ [완료] 배우 35: '배우 이동규, 성별: male, 나이: 34, 키: 184cm, 몸무게: 77kg' 처리됨
# ✅ [완료] 배우 36: '배우 최재건, 성별: male, 나이: 26, 키: 185cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 37: '배우 김태영, 성별: male, 나이: 29, 키: 176cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 38: '배우 김성인, 성별: male, 나이: 35, 키: 173cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 39: '배우 오창준, 성별: male, 나이: 29, 키: 185cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 40: '배우 이로운, 성별: male, 나이: 30, 키: 177cm, 몸무게: 77kg' 처리됨
# ✅ [완료] 배우 41: '배우 고유철, 성별: male, 나이: 56, 키: 183cm, 몸무게: 83kg' 처리됨
# ✅ [완료] 배우 42: '배우 엄태준, 성별: male, 나이: 28, 키: 177cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 43: '배우 김선진, 성별: male, 나이: 33, 키: 180cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 44: '배우 조호현, 성별: male, 나이: 37, 키: 172cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 45: '배우 윤지홍, 성별: male, 나이: 36, 키: 172cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 46: '배우 한승혁, 성별: male, 나이: 26, 키: 183cm, 몸무게: 83kg' 처리됨
# ✅ [완료] 배우 47: '배우 황인우, 성별: male, 나이: 25, 키: 178cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 48: '배우 최찬이, 성별: male, 나이: 30, 키: 180cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 49: '배우 전수환, 성별: male, 나이: 19, 키: 183cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 50: '배우 서호준, 성별: male, 나이: 33, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 51: '배우 유창균, 성별: male, 나이: 34, 키: 176cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 52: '배우 우희상, 성별: male, 나이: 26, 키: 173cm, 몸무게: 54kg' 처리됨
# ✅ [완료] 배우 53: '배우 Jonathan, 성별: male, 나이: 29, 키: 180cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 54: '배우 이상문, 성별: male, 나이: 12, 키: 152cm, 몸무게: 45kg' 처리됨
# ✅ [완료] 배우 55: '배우 정성우, 성별: male, 나이: 27, 키: 176cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 56: '배우 김태완, 성별: male, 나이: 23, 키: 174cm, 몸무게: 58kg' 처리됨
# ✅ [완료] 배우 57: '배우 문하랑, 성별: male, 나이: 5, 키: 100cm, 몸무게: 15.5kg' 처리됨
# ✅ [완료] 배우 58: '배우 정 예 현, 성별: male, 나이: 5, 키: 114cm, 몸무게: 20kg' 처리됨
# ✅ [완료] 배우 59: '배우 박정우, 성별: male, 나이: 30, 키: 174cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 60: '배우 배도현, 성별: male, 나이: 26, 키: 182cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 61: '배우 박휘노, 성별: male, 나이: 29, 키: 182cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 62: '배우 김민성, 성별: male, 나이: 6, 키: 114cm, 몸무게: 19kg' 처리됨
# ✅ [완료] 배우 63: '배우 김현구, 성별: male, 나이: 21, 키: 175cm, 몸무게: 58kg' 처리됨
# ✅ [완료] 배우 64: '배우 박건우, 성별: male, 나이: 33, 키: 181cm, 몸무게: 70kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 65: '배우 이규민, 성별: male, 나이: 23, 키: 183cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 66: '배우 서동복, 성별: male, 나이: 35, 키: 180cm, 몸무게: 78kg' 처리됨
# ✅ [완료] 배우 67: '배우 김동철, 성별: male, 나이: 69, 키: 167cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 68: '배우 송성민, 성별: male, 나이: 26, 키: 171cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 69: '배우 박종찬, 성별: male, 나이: 26, 키: 170cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 70: '배우 김다익, 성별: male, 나이: 30, 키: 175cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 71: '배우 김유민, 성별: male, 나이: 21, 키: 175cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 72: '배우 문강주, 성별: male, 나이: 32, 키: 178cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 73: '배우 이은준, 성별: male, 나이: 26, 키: 184cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 74: '배우 박송재, 성별: male, 나이: 30, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 75: '배우 이강식, 성별: male, 나이: 42, 키: 189cm, 몸무게: 83kg' 처리됨
# ✅ [완료] 배우 76: '배우 정예찬, 성별: male, 나이: 29, 키: 179cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 77: '배우 남도일, 성별: male, 나이: 29, 키: 174cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 78: '배우 박유신, 성별: male, 나이: 1, 키: 74cm, 몸무게: 10kg' 처리됨
# ✅ [완료] 배우 79: '배우 변지훈, 성별: male, 나이: 20, 키: 179cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 80: '배우 김겸재, 성별: male, 나이: 23, 키: 175cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 81: '배우 황형철, 성별: male, 나이: 24, 키: 175cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 82: '배우 나성현, 성별: male, 나이: 25, 키: 177cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 83: '배우 김한빈, 성별: male, 나이: 29, 키: 175cm, 몸무게: 59kg' 처리됨
# ✅ [완료] 배우 84: '배우 전현우, 성별: male, 나이: 25, 키: 170cm, 몸무게: 56kg' 처리됨
# ✅ [완료] 배우 85: '배우 한도윤, 성별: male, 나이: 32, 키: 184cm, 몸무게: 79kg' 처리됨
# ✅ [완료] 배우 86: '배우 문정우, 성별: male, 나이: 25, 키: 180cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 87: '배우 박희수, 성별: male, 나이: 29, 키: 176cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 88: '배우 이명석, 성별: male, 나이: 26, 키: 181cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 89: '배우 이학민, 성별: male, 나이: 30, 키: 186cm, 몸무게: 117kg' 처리됨
# ✅ [완료] 배우 90: '배우 최은호, 성별: male, 나이: 17, 키: 181cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 91: '배우 송우혁, 성별: male, 나이: 20, 키: 173cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 92: '배우 이로이, 성별: male, 나이: 2, 키: 90cm, 몸무게: 13kg' 처리됨
# ✅ [완료] 배우 93: '배우 신재인, 성별: male, 나이: 28, 키: 183cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 94: '배우 이지환, 성별: male, 나이: 24, 키: 183cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 95: '배우 김걸, 성별: male, 나이: 23, 키: 186cm, 몸무게: 85kg' 처리됨
# ✅ [완료] 배우 96: '배우 장시훈, 성별: male, 나이: 20, 키: 174cm, 몸무게: 59kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 97: '배우 이동현, 성별: male, 나이: 28, 키: 174cm, 몸무게: 59kg' 처리됨
# ✅ [완료] 배우 98: '배우 노정욱, 성별: male, 나이: 15, 키: 167cm, 몸무게: 57kg' 처리됨
# ✅ [완료] 배우 99: '배우 강동완, 성별: male, 나이: 30, 키: 178cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 100: '배우 오우영, 성별: male, 나이: 31, 키: 174cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 101: '배우 정하늘, 성별: male, 나이: 31, 키: 167cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 102: '배우 김태영, 성별: male, 나이: 24, 키: 170cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 103: '배우 어진리, 성별: male, 나이: 38, 키: 174cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 104: '배우 배재일, 성별: male, 나이: 28, 키: 182cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 105: '배우 도진우, 성별: male, 나이: 32, 키: 170cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 106: '배우 김성환, 성별: male, 나이: 31, 키: 180cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 107: '배우 조남호, 성별: male, 나이: 65, 키: 174cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 108: '배우 문병설, 성별: male, 나이: 34, 키: 178cm, 몸무게: 78kg' 처리됨
# ✅ [완료] 배우 109: '배우 호사인, 성별: male, 나이: 36, 키: 160cm, 몸무게: 54kg' 처리됨
# ✅ [완료] 배우 110: '배우 민준기, 성별: male, 나이: 32, 키: 175cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 111: '배우 김도윤, 성별: male, 나이: 8, 키: 125cm, 몸무게: 25kg' 처리됨
# ✅ [완료] 배우 112: '배우 정승환, 성별: male, 나이: 26, 키: 184cm, 몸무게: 88kg' 처리됨
# ✅ [완료] 배우 113: '배우 홍도형, 성별: male, 나이: 30, 키: 161cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 114: '배우 정승훈, 성별: male, 나이: 31, 키: 178cm, 몸무게: 78kg' 처리됨
# ✅ [완료] 배우 115: '배우 강영원, 성별: male, 나이: 34, 키: 175cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 116: '배우 이지성, 성별: male, 나이: 16, 키: 174cm, 몸무게: 76kg' 처리됨
# ✅ [완료] 배우 117: '배우 박준영, 성별: male, 나이: 25, 키: 182cm, 몸무게: 87kg' 처리됨
# ✅ [완료] 배우 118: '배우 김현, 성별: male, 나이: 26, 키: 176cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 119: '배우 최광균, 성별: male, 나이: 26, 키: 181cm, 몸무게: 81kg' 처리됨
# ✅ [완료] 배우 120: '배우 김동은, 성별: male, 나이: 30, 키: 179cm, 몸무게: 85kg' 처리됨
# ✅ [완료] 배우 121: '배우 파르하트, 성별: male, 나이: 35, 키: 180cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 122: '배우 이철규, 성별: male, 나이: 24, 키: 165cm, 몸무게: 53kg' 처리됨
# ✅ [완료] 배우 123: '배우 김찬우, 성별: male, 나이: 23, 키: 174cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 124: '배우 이영석, 성별: male, 나이: 24, 키: 174cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 125: '배우 콘스탄틴 칸, 성별: male, 나이: 27, 키: 183cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 126: '배우 서준혁, 성별: male, 나이: 27, 키: 176cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 127: '배우 김준환, 성별: male, 나이: 43, 키: 172cm, 몸무게: 88kg' 처리됨
# ✅ [완료] 배우 128: '배우 이승훈, 성별: male, 나이: 25, 키: 174cm, 몸무게: 65kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 129: '배우 김현진, 성별: male, 나이: 30, 키: 187cm, 몸무게: 78kg' 처리됨
# ✅ [완료] 배우 130: '배우 정지호, 성별: male, 나이: 30, 키: 177cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 131: '배우 문승훈, 성별: male, 나이: 27, 키: 170cm, 몸무게: 58kg' 처리됨
# ✅ [완료] 배우 132: '배우 소현철, 성별: male, 나이: 57, 키: 182cm, 몸무게: 87kg' 처리됨
# ✅ [완료] 배우 133: '배우 강우, 성별: male, 나이: 33, 키: 170cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 134: '배우 김동준, 성별: male, 나이: 23, 키: 186cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 135: '배우 황영국, 성별: male, 나이: 24, 키: 177cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 136: '배우 Yesset, 성별: male, 나이: 25, 키: 175cm, 몸무게: 52kg' 처리됨
# ✅ [완료] 배우 137: '배우 박지원, 성별: male, 나이: 26, 키: 177cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 138: '배우 정민수, 성별: male, 나이: 8, 키: 126cm, 몸무게: 21kg' 처리됨
# ✅ [완료] 배우 139: '배우 김민주, 성별: male, 나이: 20, 키: 182cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 140: '배우 오현빈, 성별: male, 나이: 25, 키: 182cm, 몸무게: 90kg' 처리됨
# ✅ [완료] 배우 141: '배우 천우영, 성별: male, 나이: 40, 키: 167cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 142: '배우 이명준, 성별: male, 나이: 30, 키: 178cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 143: '배우 박지훈, 성별: male, 나이: 24, 키: 179cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 144: '배우 김찬호, 성별: male, 나이: 31, 키: 178cm, 몸무게: 77kg' 처리됨
# ✅ [완료] 배우 145: '배우 김재성, 성별: male, 나이: 27, 키: 177cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 146: '배우 박찬용, 성별: male, 나이: 19, 키: 173cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 147: '배우 윤찬, 성별: male, 나이: 16, 키: 181cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 148: '배우 서윤재, 성별: male, 나이: 7, 키: 111cm, 몸무게: 20kg' 처리됨
# ✅ [완료] 배우 149: '배우 이창노, 성별: male, 나이: 26, 키: 176cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 150: '배우 김영우, 성별: male, 나이: 20, 키: 178cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 151: '배우 김루빈, 성별: male, 나이: 42, 키: 177.5cm, 몸무게: 85kg' 처리됨
# ✅ [완료] 배우 152: '배우 장재호, 성별: male, 나이: 28, 키: 192cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 153: '배우 김진천, 성별: male, 나이: 46, 키: 180cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 154: '배우 성우진, 성별: male, 나이: 1, 키: 74cm, 몸무게: 9.2kg' 처리됨
# ✅ [완료] 배우 155: '배우 김도현, 성별: male, 나이: 22, 키: 178cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 156: '배우 김세환, 성별: male, 나이: 37, 키: 180cm, 몸무게: 76kg' 처리됨
# ✅ [완료] 배우 157: '배우 이태오, 성별: male, 나이: 2, 키: 79cm, 몸무게: 10kg' 처리됨
# ✅ [완료] 배우 158: '배우 김로운, 성별: male, 나이: 3, 키: 95cm, 몸무게: 15kg' 처리됨
# ✅ [완료] 배우 159: '배우 이태훈, 성별: male, 나이: 32, 키: 183cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 160: '배우 강선호, 성별: male, 나이: 28, 키: 184cm, 몸무게: 68kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 161: '배우 김건우, 성별: male, 나이: 42, 키: 180cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 162: '배우 장인제, 성별: male, 나이: 26, 키: 174cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 163: '배우 김지안, 성별: male, 나이: 11, 키: 142cm, 몸무게: 33kg' 처리됨
# ✅ [완료] 배우 164: '배우 정영재, 성별: male, 나이: 32, 키: 170cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 165: '배우 이지혜, 성별: male, 나이: 29, 키: 172cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 166: '배우 전종배, 성별: male, 나이: 59, 키: 170cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 167: '배우 이범기, 성별: male, 나이: 31, 키: 177cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 168: '배우 김민수, 성별: male, 나이: 24, 키: 173cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 169: '배우 홍지환, 성별: male, 나이: 9, 키: 130cm, 몸무게: 24kg' 처리됨
# ✅ [완료] 배우 170: '배우 장성원, 성별: male, 나이: 26, 키: 173cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 171: '배우 이민후, 성별: male, 나이: 27, 키: 180cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 172: '배우 정태영, 성별: male, 나이: 23, 키: 180cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 173: '배우 박건호, 성별: male, 나이: 7, 키: 129cm, 몸무게: 24kg' 처리됨
# ✅ [완료] 배우 174: '배우 최영호, 성별: male, 나이: 69, 키: 172cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 175: '배우 오희석, 성별: male, 나이: 33, 키: 174cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 176: '배우 임준범, 성별: male, 나이: 28, 키: 164cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 177: '배우 박연길, 성별: male, 나이: 46, 키: 181cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 178: '배우 이소담, 성별: male, 나이: 2, 키: 79cm, 몸무게: 12kg' 처리됨
# ✅ [완료] 배우 179: '배우 이도담, 성별: male, 나이: 3, 키: 89cm, 몸무게: 14kg' 처리됨
# ✅ [완료] 배우 180: '배우 김대훈, 성별: male, 나이: 27, 키: 177cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 181: '배우 소현철, 성별: male, 나이: 57, 키: 182cm, 몸무게: 87kg' 처리됨
# ✅ [완료] 배우 182: '배우 이찬영, 성별: male, 나이: 25, 키: 175cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 183: '배우 송교빈, 성별: male, 나이: 36, 키: 180cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 184: '배우 이정민, 성별: male, 나이: 24, 키: 171cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 185: '배우 정규영, 성별: male, 나이: 27, 키: 182cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 186: '배우 류현우, 성별: male, 나이: 29, 키: 188cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 187: '배우 이상민, 성별: male, 나이: 31, 키: 178cm, 몸무게: 100kg' 처리됨
# ✅ [완료] 배우 188: '배우 김서현, 성별: male, 나이: 23, 키: 184cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 189: '배우 신중한, 성별: male, 나이: 51, 키: 173cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 190: '배우 강수호, 성별: male, 나이: 6, 키: 112cm, 몸무게: 22kg' 처리됨
# ✅ [완료] 배우 191: '배우 독고광, 성별: male, 나이: 32, 키: 170cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 192: '배우 김재형, 성별: male, 나이: 28, 키: 183cm, 몸무게: 77kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 193: '배우 강민승, 성별: male, 나이: 39, 키: 177cm, 몸무게: 85kg' 처리됨
# ✅ [완료] 배우 194: '배우 황지우, 성별: male, 나이: 9, 키: 134cm, 몸무게: 31kg' 처리됨
# ✅ [완료] 배우 195: '배우 승완, 성별: male, 나이: 32, 키: 176cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 196: '배우 김경윤, 성별: male, 나이: 25, 키: 175cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 197: '배우 이하늘, 성별: male, 나이: 29, 키: 173cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 198: '배우 이도영, 성별: male, 나이: 24, 키: 177cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 199: '배우 임종찬, 성별: male, 나이: 31, 키: 174cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 200: '배우 오창민, 성별: male, 나이: 17, 키: 184cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 201: '배우 박지홍, 성별: male, 나이: 27, 키: 183cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 202: '배우 태성, 성별: male, 나이: 37, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 203: '배우 김영욱, 성별: male, 나이: 29, 키: 180cm, 몸무게: 83kg' 처리됨
# ✅ [완료] 배우 204: '배우 김민준, 성별: male, 나이: 27, 키: 185cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 205: '배우 강태영, 성별: male, 나이: 24, 키: 185cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 206: '배우 윤이준, 성별: male, 나이: 4, 키: 102cm, 몸무게: 18kg' 처리됨
# ✅ [완료] 배우 207: '배우 김연호, 성별: male, 나이: 32, 키: 183cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 208: '배우 정민혁, 성별: male, 나이: 29, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 209: '배우 한예준, 성별: male, 나이: 23, 키: 182cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 210: '배우 지윤성, 성별: male, 나이: 31, 키: 178cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 211: '배우 임승현, 성별: male, 나이: 24, 키: 190cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 212: '배우 이원재, 성별: male, 나이: 25, 키: 179cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 213: '배우 김준형, 성별: male, 나이: 30, 키: 178cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 214: '배우 최준수, 성별: male, 나이: 24, 키: 179cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 215: '배우 김정빈, 성별: male, 나이: 25, 키: 175cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 216: '배우 정호연, 성별: male, 나이: 24, 키: 174cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 217: '배우 이제광, 성별: male, 나이: 20, 키: 185cm, 몸무게: 89kg' 처리됨
# ✅ [완료] 배우 218: '배우 강슬기, 성별: male, 나이: 27, 키: 181cm, 몸무게: 89kg' 처리됨
# ✅ [완료] 배우 219: '배우 이 필, 성별: male, 나이: 51, 키: 181cm, 몸무게: 89kg' 처리됨
# ✅ [완료] 배우 220: '배우 진혁, 성별: male, 나이: 29, 키: 173cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 221: '배우 황보재한, 성별: male, 나이: 7, 키: 117cm, 몸무게: 20kg' 처리됨
# ✅ [완료] 배우 222: '배우 김태환, 성별: male, 나이: 28, 키: 179cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 223: '배우 최우리, 성별: male, 나이: 41, 키: 181cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 224: '배우 양지욱, 성별: male, 나이: 25, 키: 176cm, 몸무게: 70kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 225: '배우 정지용, 성별: male, 나이: 18, 키: 175cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 226: '배우 허원, 성별: male, 나이: 25, 키: 176cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 227: '배우 김연준, 성별: male, 나이: 27, 키: 182cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 228: '배우 박광현, 성별: male, 나이: 29, 키: 172cm, 몸무게: 82kg' 처리됨
# ✅ [완료] 배우 229: '배우 김하용, 성별: male, 나이: 26, 키: 186cm, 몸무게: 77kg' 처리됨
# ✅ [완료] 배우 230: '배우 장기남, 성별: male, 나이: 29, 키: 180cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 231: '배우 박진홍, 성별: male, 나이: 29, 키: 186cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 232: '배우 권반석, 성별: male, 나이: 44, 키: 180cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 233: '배우 이민재, 성별: male, 나이: 25, 키: 179cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 234: '배우 양병준, 성별: male, 나이: 28, 키: 176cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 235: '배우 전찬호, 성별: male, 나이: 26, 키: 173cm, 몸무게: 58kg' 처리됨
# ✅ [완료] 배우 236: '배우 김온유, 성별: male, 나이: 11, 키: 133cm, 몸무게: 31kg' 처리됨
# ✅ [완료] 배우 237: '배우 조형주 David Cho, 성별: male, 나이: 29, 키: 173cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 238: '배우 박지후, 성별: male, 나이: 5, 키: 107cm, 몸무게: 18kg' 처리됨
# ✅ [완료] 배우 239: '배우 한새벽, 성별: male, 나이: 24, 키: 173cm, 몸무게: 59kg' 처리됨
# ✅ [완료] 배우 240: '배우 한태경, 성별: male, 나이: 30, 키: 177cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 241: '배우 오태식, 성별: male, 나이: 24, 키: 178cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 242: '배우 김우선, 성별: male, 나이: 37, 키: 177cm, 몸무게: 79kg' 처리됨
# ✅ [완료] 배우 243: '배우 김건, 성별: male, 나이: 29, 키: 183cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 244: '배우 백성일, 성별: male, 나이: 36, 키: 175cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 245: '배우 조민찬, 성별: male, 나이: 23, 키: 172cm, 몸무게: 54kg' 처리됨
# ✅ [완료] 배우 246: '배우 이혁, 성별: male, 나이: 43, 키: 182cm, 몸무게: 105kg' 처리됨
# ✅ [완료] 배우 247: '배우 전상헌, 성별: male, 나이: 28, 키: 181cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 248: '배우 조윤상, 성별: male, 나이: 37, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 249: '배우 노리암, 성별: male, 나이: 1, 키: 77cm, 몸무게: 10.3kg' 처리됨
# ✅ [완료] 배우 250: '배우 류한종, 성별: male, 나이: 30, 키: 185cm, 몸무게: 110kg' 처리됨
# ✅ [완료] 배우 251: '배우 최희망, 성별: male, 나이: 20, 키: 176cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 252: '배우 손현준, 성별: male, 나이: 27, 키: 183cm, 몸무게: 87kg' 처리됨
# ✅ [완료] 배우 253: '배우 장도준, 성별: male, 나이: 26, 키: 165cm, 몸무게: 59kg' 처리됨
# ✅ [완료] 배우 254: '배우 길경민, 성별: male, 나이: 24, 키: 183cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 255: '배우 조영빈, 성별: male, 나이: 32, 키: 174cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 256: '배우 안드레이, 성별: male, 나이: 34, 키: 180cm, 몸무게: 62kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 257: '배우 이원찬, 성별: male, 나이: 21, 키: 185cm, 몸무게: 76kg' 처리됨
# ✅ [완료] 배우 258: '배우 홍덕기, 성별: male, 나이: 28, 키: 167cm, 몸무게: 85kg' 처리됨
# ✅ [완료] 배우 259: '배우 밀러 채드 (Chad Miller), 성별: male, 나이: 34, 키: 175cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 260: '배우 김병탁, 성별: male, 나이: 26, 키: 174cm, 몸무게: 110kg' 처리됨
# ✅ [완료] 배우 261: '배우 한세환, 성별: male, 나이: 25, 키: 186cm, 몸무게: 85kg' 처리됨
# ✅ [완료] 배우 262: '배우 송명찬, 성별: male, 나이: 23, 키: 175cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 263: '배우 조영익, 성별: male, 나이: 28, 키: 183cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 264: '배우 이대겸, 성별: male, 나이: 24, 키: 188cm, 몸무게: 76kg' 처리됨
# ✅ [완료] 배우 265: '배우 최우진, 성별: male, 나이: 13, 키: 154cm, 몸무게: 40kg' 처리됨
# ✅ [완료] 배우 266: '배우 김동규, 성별: male, 나이: 14, 키: 165cm, 몸무게: 55kg' 처리됨
# ✅ [완료] 배우 267: '배우 황종민, 성별: male, 나이: 25, 키: 178cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 268: '배우 김영호, 성별: male, 나이: 29, 키: 173cm, 몸무게: 52kg' 처리됨
# ✅ [완료] 배우 269: '배우 신대근, 성별: male, 나이: 25, 키: 167cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 270: '배우 김대광, 성별: male, 나이: 30, 키: 187cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 271: '배우 정시온, 성별: male, 나이: 8, 키: 128cm, 몸무게: 26kg' 처리됨
# ✅ [완료] 배우 272: '배우 김민서, 성별: male, 나이: 25, 키: 178cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 273: '배우 김영호, 성별: male, 나이: 39, 키: 173cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 274: '배우 정한솔, 성별: male, 나이: 9, 키: 135cm, 몸무게: 40kg' 처리됨
# ✅ [완료] 배우 275: '배우 정지우, 성별: male, 나이: 24, 키: 181cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 276: '배우 강승균, 성별: male, 나이: 63, 키: 173cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 277: '배우 임은욱, 성별: male, 나이: 38, 키: 167cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 278: '배우 유태웅, 성별: male, 나이: 67, 키: 173cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 279: '배우 전한결, 성별: male, 나이: 18, 키: 182cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 280: '배우 정신혁, 성별: male, 나이: 19, 키: 180cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 281: '배우 박상준, 성별: male, 나이: 19, 키: 175cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 282: '배우 안민혁, 성별: male, 나이: 24, 키: 182cm, 몸무게: 94kg' 처리됨
# ✅ [완료] 배우 283: '배우 현주니, 성별: male, 나이: 3, 키: 90.7cm, 몸무게: 14.5kg' 처리됨
# ✅ [완료] 배우 284: '배우 황다민, 성별: male, 나이: 2, 키: 78cm, 몸무게: 11kg' 처리됨
# ✅ [완료] 배우 285: '배우 김진웅, 성별: male, 나이: 42, 키: 182cm, 몸무게: 79kg' 처리됨
# ✅ [완료] 배우 286: '배우 조민욱, 성별: male, 나이: 31, 키: 187cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 287: '배우 이창현, 성별: male, 나이: 37, 키: 168cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 288: '배우 세바 SEBA (외국 외국인), 성별: male, 나이: 46, 키: 188cm, 몸무게: 71kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 289: '배우 최준홍, 성별: male, 나이: 27, 키: 174cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 290: '배우 박재이, 성별: male, 나이: 18, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 291: '배우 김용로, 성별: male, 나이: 26, 키: 183cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 292: '배우 전강희, 성별: male, 나이: 10, 키: 140cm, 몸무게: 38kg' 처리됨
# ✅ [완료] 배우 293: '배우 조순정, 성별: male, 나이: 33, 키: 170cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 294: '배우 장진석, 성별: male, 나이: 22, 키: 176cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 295: '배우 노태욱, 성별: male, 나이: 24, 키: 175cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 296: '배우 홍주명, 성별: male, 나이: 31, 키: 175cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 297: '배우 최동진, 성별: male, 나이: 24, 키: 175cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 298: '배우 조하승, 성별: male, 나이: 6, 키: 115cm, 몸무게: 20kg' 처리됨
# ✅ [완료] 배우 299: '배우 강은교, 성별: male, 나이: 5, 키: 113cm, 몸무게: 24kg' 처리됨
# ✅ [완료] 배우 300: '배우 이종무, 성별: male, 나이: 27, 키: 183cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 301: '배우 이기원, 성별: male, 나이: 26, 키: 183cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 302: '배우 최원재, 성별: male, 나이: 21, 키: 180cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 303: '배우 김준석, 성별: male, 나이: 42, 키: 186cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 304: '배우 이건희, 성별: male, 나이: 25, 키: 179cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 305: '배우 김병선, 성별: male, 나이: 55, 키: 175cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 306: '배우 김민서, 성별: male, 나이: 24, 키: 181cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 307: '배우 최재성, 성별: male, 나이: 27, 키: 177cm, 몸무게: 77kg' 처리됨
# ✅ [완료] 배우 308: '배우 정승교, 성별: male, 나이: 67, 키: 173cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 309: '배우 유형록, 성별: male, 나이: 28, 키: 183cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 310: '배우 정상민, 성별: male, 나이: 25, 키: 178cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 311: '배우 정의진, 성별: male, 나이: 21, 키: 173cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 312: '배우 정한서, 성별: male, 나이: 32, 키: 175cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 313: '배우 성 환, 성별: male, 나이: 42, 키: 178cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 314: '배우 김지환, 성별: male, 나이: 26, 키: 182cm, 몸무게: 78kg' 처리됨
# ✅ [완료] 배우 315: '배우 이열, 성별: male, 나이: 21, 키: 181cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 316: '배우 노지성, 성별: male, 나이: 16, 키: 176cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 317: '배우 하유준, 성별: male, 나이: 8, 키: 130cm, 몸무게: 33kg' 처리됨
# ✅ [완료] 배우 318: '배우 백승문, 성별: male, 나이: 29, 키: 173cm, 몸무게: 57kg' 처리됨
# ✅ [완료] 배우 319: '배우 박예준, 성별: male, 나이: 17, 키: 169cm, 몸무게: 55kg' 처리됨
# ✅ [완료] 배우 320: '배우 이한솔, 성별: male, 나이: 31, 키: 179cm, 몸무게: 69kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 321: '배우 박예찬, 성별: male, 나이: 22, 키: 172cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 322: '배우 강남형, 성별: male, 나이: 24, 키: 173cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 323: '배우 김홍관, 성별: male, 나이: 30, 키: 186cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 324: '배우 정우진, 성별: male, 나이: 26, 키: 170cm, 몸무게: 57kg' 처리됨
# ✅ [완료] 배우 325: '배우 도준혁, 성별: male, 나이: 34, 키: 174cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 326: '배우 박준형, 성별: male, 나이: 29, 키: 182cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 327: '배우 김기현, 성별: male, 나이: 35, 키: 175cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 328: '배우 정대성, 성별: male, 나이: 32, 키: 182cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 329: '배우 정호준, 성별: male, 나이: 22, 키: 183cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 330: '배우 김건휘, 성별: male, 나이: 20, 키: 176cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 331: '배우 김태랑, 성별: male, 나이: 25, 키: 180cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 332: '배우 김현구, 성별: male, 나이: 26, 키: 186cm, 몸무게: 78kg' 처리됨
# ✅ [완료] 배우 333: '배우 최천성, 성별: male, 나이: 31, 키: 166cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 334: '배우 오형민, 성별: male, 나이: 28, 키: 178cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 335: '배우 서용우, 성별: male, 나이: 25, 키: 178cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 336: '배우 박진영, 성별: male, 나이: 20, 키: 178cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 337: '배우 송시현, 성별: male, 나이: 25, 키: 183cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 338: '배우 최현승, 성별: male, 나이: 24, 키: 185cm, 몸무게: 78kg' 처리됨
# ✅ [완료] 배우 339: '배우 전영식, 성별: male, 나이: 48, 키: 180cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 340: '배우 양효석, 성별: male, 나이: 27, 키: 173cm, 몸무게: 66kg' 처리됨
# ✅ [완료] 배우 341: '배우 김준일, 성별: male, 나이: 26, 키: 188cm, 몸무게: 95kg' 처리됨
# ✅ [완료] 배우 342: '배우 김광영, 성별: male, 나이: 28, 키: 182cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 343: '배우 정민구, 성별: male, 나이: 46, 키: 179cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 344: '배우 이경환, 성별: male, 나이: 26, 키: 176cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 345: '배우 김현민, 성별: male, 나이: 21, 키: 184cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 346: '배우 문 산, 성별: male, 나이: 26, 키: 180cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 347: '배우 윤태현, 성별: male, 나이: 25, 키: 184cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 348: '배우 차강인, 성별: male, 나이: 29, 키: 174cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 349: '배우 이동현, 성별: male, 나이: 30, 키: 178cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 350: '배우 김현민, 성별: male, 나이: 22, 키: 168cm, 몸무게: 55kg' 처리됨
# ✅ [완료] 배우 351: '배우 김창진, 성별: male, 나이: 29, 키: 179cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 352: '배우 전호민, 성별: male, 나이: 25, 키: 180cm, 몸무게: 68kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 353: '배우 양현창, 성별: male, 나이: 26, 키: 168cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 354: '배우 이승재, 성별: male, 나이: 47, 키: 175cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 355: '배우 문병선, 성별: male, 나이: 27, 키: 178cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 356: '배우 이청연, 성별: male, 나이: 47, 키: 180cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 357: '배우 박종성, 성별: male, 나이: 23, 키: 185cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 358: '배우 김민석, 성별: male, 나이: 25, 키: 181cm, 몸무게: 76kg' 처리됨
# ✅ [완료] 배우 359: '배우 안병혁, 성별: male, 나이: 26, 키: 172cm, 몸무게: 57kg' 처리됨
# ✅ [완료] 배우 360: '배우 박준영, 성별: male, 나이: 24, 키: 178cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 361: '배우 구시우, 성별: male, 나이: 3, 키: 97cm, 몸무게: 15kg' 처리됨
# ✅ [완료] 배우 362: '배우 장우준, 성별: male, 나이: 5, 키: 109cm, 몸무게: 18kg' 처리됨
# ✅ [완료] 배우 363: '배우 김정민, 성별: male, 나이: 21, 키: 175cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 364: '배우 최환희, 성별: male, 나이: 22, 키: 182cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 365: '배우 이재율, 성별: male, 나이: 5, 키: 103cm, 몸무게: 17kg' 처리됨
# ✅ [완료] 배우 366: '배우 김수현, 성별: male, 나이: 22, 키: 177cm, 몸무게: 76kg' 처리됨
# ✅ [완료] 배우 367: '배우 김원진, 성별: male, 나이: 34, 키: 184cm, 몸무게: 85kg' 처리됨
# ✅ [완료] 배우 368: '배우 조성우, 성별: male, 나이: 27, 키: 182cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 369: '배우 최원진, 성별: male, 나이: 27, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 370: '배우 황동우, 성별: male, 나이: 34, 키: 175cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 371: '배우 박상빈, 성별: male, 나이: 20, 키: 175cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 372: '배우 박성준, 성별: male, 나이: 27, 키: 175cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 373: '배우 김준형, 성별: male, 나이: 26, 키: 177cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 374: '배우 허동희, 성별: male, 나이: 20, 키: 174cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 375: '배우 김도윤, 성별: male, 나이: 20, 키: 180cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 376: '배우 송제호, 성별: male, 나이: 17, 키: 170cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 377: '배우 최수호, 성별: male, 나이: 6, 키: 107cm, 몸무게: 18kg' 처리됨
# ✅ [완료] 배우 378: '배우 엄대현, 성별: male, 나이: 26, 키: 177cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 379: '배우 김종오, 성별: male, 나이: 28, 키: 173cm, 몸무게: 59kg' 처리됨
# ✅ [완료] 배우 380: '배우 정 원, 성별: male, 나이: 28, 키: 172cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 381: '배우 유대환, 성별: male, 나이: 30, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 382: '배우 정찬민, 성별: male, 나이: 19, 키: 172cm, 몸무게: 59kg' 처리됨
# ✅ [완료] 배우 383: '배우 김범준, 성별: male, 나이: 31, 키: 182cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 384: '배우 기성규, 성별: male, 나이: 26, 키: 184cm, 몸무게: 111kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 385: '배우 윤성현, 성별: male, 나이: 9, 키: 140cm, 몸무게: 32kg' 처리됨
# ✅ [완료] 배우 386: '배우 만성욱, 성별: male, 나이: 40, 키: 180cm, 몸무게: 83kg' 처리됨
# ✅ [완료] 배우 387: '배우 강희망, 성별: male, 나이: 1, 키: 65cm, 몸무게: 7.5kg' 처리됨
# ✅ [완료] 배우 388: '배우 민서준, 성별: male, 나이: 10, 키: 130cm, 몸무게: 25kg' 처리됨
# ✅ [완료] 배우 389: '배우 정진욱, 성별: male, 나이: 24, 키: 177cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 390: '배우 최로건, 성별: male, 나이: 5, 키: 101cm, 몸무게: 17kg' 처리됨
# ✅ [완료] 배우 391: '배우 선영원, 성별: male, 나이: 23, 키: 174cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 392: '배우 박진성, 성별: male, 나이: 18, 키: 178cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 393: '배우 신기준, 성별: male, 나이: 29, 키: 180cm, 몸무게: 78kg' 처리됨
# ✅ [완료] 배우 394: '배우 김주성, 성별: male, 나이: 19, 키: 184cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 395: '배우 이경호, 성별: male, 나이: 31, 키: 173cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 396: '배우 홍빈, 성별: male, 나이: 29, 키: 173cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 397: '배우 조우재, 성별: male, 나이: 23, 키: 175cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 398: '배우 임준영, 성별: male, 나이: 26, 키: 180cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 399: '배우 김도훈, 성별: male, 나이: 17, 키: 175cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 400: '배우 강다빈, 성별: male, 나이: 33, 키: 188cm, 몸무게: 83kg' 처리됨
# ✅ [완료] 배우 401: '배우 이루인, 성별: male, 나이: 6, 키: 113cm, 몸무게: 21kg' 처리됨
# ✅ [완료] 배우 402: '배우 Miguel / 미겔, 성별: male, 나이: 21, 키: 175cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 403: '배우 이창주, 성별: male, 나이: 29, 키: 176cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 404: '배우 박건수, 성별: male, 나이: 31, 키: 181cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 405: '배우 이다온, 성별: male, 나이: 5, 키: 105cm, 몸무게: 18kg' 처리됨
# ✅ [완료] 배우 406: '배우 이민규, 성별: male, 나이: 26, 키: 174cm, 몸무게: 61kg' 처리됨
# ✅ [완료] 배우 407: '배우 Bastien/박시안, 성별: male, 나이: 32, 키: 180cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 408: '배우 장동익, 성별: male, 나이: 31, 키: 186cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 409: '배우 최정원, 성별: male, 나이: 33, 키: 180cm, 몸무게: 95kg' 처리됨
# ✅ [완료] 배우 410: '배우 이찬우, 성별: male, 나이: 18, 키: 175cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 411: '배우 이상길, 성별: male, 나이: 31, 키: 177cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 412: '배우 손단, 성별: male, 나이: 36, 키: 180cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 413: '배우 안재형, 성별: male, 나이: 25, 키: 167cm, 몸무게: 56kg' 처리됨
# ✅ [완료] 배우 414: '배우 최성호, 성별: male, 나이: 29, 키: 183cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 415: '배우 임대중, 성별: male, 나이: 21, 키: 176cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 416: '배우 이준호, 성별: male, 나이: 33, 키: 178cm, 몸무게: 80kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 417: '배우 박선우, 성별: male, 나이: 29, 키: 189cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 418: '배우 연현수, 성별: male, 나이: 24, 키: 183cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 419: '배우 이용규, 성별: male, 나이: 34, 키: 172cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 420: '배우 김태섭, 성별: male, 나이: 28, 키: 176cm, 몸무게: 66kg' 처리됨
# ✅ [완료] 배우 421: '배우 김예찬, 성별: male, 나이: 18, 키: 174cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 422: '배우 최지헌, 성별: male, 나이: 8, 키: 122cm, 몸무게: 26kg' 처리됨
# ✅ [완료] 배우 423: '배우 임태관, 성별: male, 나이: 33, 키: 175cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 424: '배우 하태원, 성별: male, 나이: 33, 키: 184cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 425: '배우 김산, 성별: male, 나이: 24, 키: 181cm, 몸무게: 77kg' 처리됨
# ✅ [완료] 배우 426: '배우 염태오, 성별: male, 나이: 14, 키: 157cm, 몸무게: 47kg' 처리됨
# ✅ [완료] 배우 427: '배우 정다운, 성별: male, 나이: 24, 키: 178cm, 몸무게: 98kg' 처리됨
# ✅ [완료] 배우 428: '배우 이호준, 성별: male, 나이: 27, 키: 176cm, 몸무게: kg' 처리됨
# ✅ [완료] 배우 429: '배우 최유찬, 성별: male, 나이: 10, 키: 140cm, 몸무게: 30kg' 처리됨
# ✅ [완료] 배우 430: '배우 송호성, 성별: male, 나이: 30, 키: 178cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 431: '배우 박재성, 성별: male, 나이: 20, 키: 175cm, 몸무게: 88kg' 처리됨
# ✅ [완료] 배우 432: '배우 소규호, 성별: male, 나이: 25, 키: 178cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 433: '배우 서하원, 성별: male, 나이: 7, 키: 118cm, 몸무게: 22kg' 처리됨
# ✅ [완료] 배우 434: '배우 이지환, 성별: male, 나이: 28, 키: 184cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 435: '배우 이동희, 성별: male, 나이: 8, 키: 126cm, 몸무게: 26kg' 처리됨
# ✅ [완료] 배우 436: '배우 송아론, 성별: male, 나이: 10, 키: 136cm, 몸무게: 26kg' 처리됨
# ✅ [완료] 배우 437: '배우 윤찬, 성별: male, 나이: 26, 키: 175cm, 몸무게: 60kg' 처리됨
# ✅ [완료] 배우 438: '배우 박준성, 성별: male, 나이: 22, 키: 177cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 439: '배우 송찬휘, 성별: male, 나이: 23, 키: 180cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 440: '배우 홍대교, 성별: male, 나이: 25, 키: 174cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 441: '배우 권재하, 성별: male, 나이: 60, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 442: '배우 전용원, 성별: male, 나이: 25, 키: 175cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 443: '배우 김제훈, 성별: male, 나이: 25, 키: 181cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 444: '배우 황인재, 성별: male, 나이: 28, 키: 176cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 445: '배우 윤이현, 성별: male, 나이: 25, 키: 183cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 446: '배우 이찬빈, 성별: male, 나이: 26, 키: 184cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 447: '배우 김은재, 성별: male, 나이: 7, 키: 112cm, 몸무게: 21kg' 처리됨
# ✅ [완료] 배우 448: '배우 김민교, 성별: male, 나이: 30, 키: 183cm, 몸무게: 71kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 449: '배우 이승필, 성별: male, 나이: 57, 키: 168cm, 몸무게: 66kg' 처리됨
# ✅ [완료] 배우 450: '배우 박헌주, 성별: male, 나이: 62, 키: 175cm, 몸무게: 58kg' 처리됨
# ✅ [완료] 배우 451: '배우 송은우, 성별: male, 나이: 8, 키: 115cm, 몸무게: 22kg' 처리됨
# ✅ [완료] 배우 452: '배우 구석준, 성별: male, 나이: 23, 키: 177cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 453: '배우 유지훈, 성별: male, 나이: 56, 키: 184cm, 몸무게: 77kg' 처리됨
# ✅ [완료] 배우 454: '배우 김동현, 성별: male, 나이: 20, 키: 187cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 455: '배우 문한결, 성별: male, 나이: 7, 키: 118cm, 몸무게: 20kg' 처리됨
# ✅ [완료] 배우 456: '배우 노규민, 성별: male, 나이: 32, 키: 180cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 457: '배우 강희건, 성별: male, 나이: 30, 키: 184cm, 몸무게: 80kg' 처리됨
# ✅ [완료] 배우 458: '배우 조성철, 성별: male, 나이: 26, 키: 169cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 459: '배우 윤서진, 성별: male, 나이: 6, 키: 113cm, 몸무게: 20kg' 처리됨
# ✅ [완료] 배우 460: '배우 김정석, 성별: male, 나이: 26, 키: 177cm, 몸무게: 71kg' 처리됨
# ✅ [완료] 배우 461: '배우 한승민, 성별: male, 나이: 23, 키: 177cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 462: '배우 노명섭, 성별: male, 나이: 34, 키: 180cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 463: '배우 홍인표, 성별: male, 나이: 39, 키: 182cm, 몸무게: 92kg' 처리됨
# ✅ [완료] 배우 464: '배우 황수민, 성별: male, 나이: 23, 키: 180cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 465: '배우 백운호, 성별: male, 나이: 27, 키: 180cm, 몸무게: 84kg' 처리됨
# ✅ [완료] 배우 466: '배우 손영광, 성별: male, 나이: 29, 키: 178cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 467: '배우 변정훈, 성별: male, 나이: 25, 키: 175cm, 몸무게: 56kg' 처리됨
# ✅ [완료] 배우 468: '배우 함솔민, 성별: male, 나이: 17, 키: 172cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 469: '배우 최승환, 성별: male, 나이: 23, 키: 184.6cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 470: '배우 전종우, 성별: male, 나이: 31, 키: 173cm, 몸무게: 64kg' 처리됨
# ✅ [완료] 배우 471: '배우 유병규, 성별: male, 나이: 31, 키: 176cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 472: '배우 박경일, 성별: male, 나이: 45, 키: 177cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 473: '배우 한도형, 성별: male, 나이: 23, 키: 175cm, 몸무게: 62kg' 처리됨
# ✅ [완료] 배우 474: '배우 김영돈, 성별: male, 나이: 31, 키: 186cm, 몸무게: 82kg' 처리됨
# ✅ [완료] 배우 475: '배우 김길홍, 성별: male, 나이: 40, 키: 186cm, 몸무게: 84kg' 처리됨
# ✅ [완료] 배우 476: '배우 유재권, 성별: male, 나이: 8, 키: 124cm, 몸무게: 27kg' 처리됨
# ✅ [완료] 배우 477: '배우 이승재, 성별: male, 나이: 29, 키: 166cm, 몸무게: 46kg' 처리됨
# ✅ [완료] 배우 478: '배우 한시헌, 성별: male, 나이: 24, 키: 177cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 479: '배우 홍요섭, 성별: male, 나이: 41, 키: 168cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 480: '배우 이시우, 성별: male, 나이: 29, 키: 170cm, 몸무게: 58kg' 처리됨
# 🔄 [배치 처리] 32명 특징 벡터 추출 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
# ✅ [완료] 배우 481: '배우 이경헌, 성별: male, 나이: 29, 키: 180cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 482: '배우 이동진, 성별: male, 나이: 35, 키: 183cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 483: '배우 황윤상, 성별: male, 나이: 42, 키: 182cm, 몸무게: 75kg' 처리됨
# ✅ [완료] 배우 484: '배우 박소산, 성별: male, 나이: 40, 키: 175cm, 몸무게: 65kg' 처리됨
# ✅ [완료] 배우 485: '배우 김재훈, 성별: male, 나이: 31, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 486: '배우 김경수, 성별: male, 나이: 26, 키: 180cm, 몸무게: 68kg' 처리됨
# ✅ [완료] 배우 487: '배우 백준우, 성별: male, 나이: 30, 키: 181cm, 몸무게: 66kg' 처리됨
# ✅ [완료] 배우 488: '배우 권승구, 성별: male, 나이: 29, 키: 178cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 489: '배우 김민환, 성별: male, 나이: 32, 키: 178cm, 몸무게: 77kg' 처리됨
# ✅ [완료] 배우 490: '배우 김율호, 성별: male, 나이: 40, 키: 180cm, 몸무게: 74kg' 처리됨
# ✅ [완료] 배우 491: '배우 이상화, 성별: male, 나이: 24, 키: 184cm, 몸무게: 81kg' 처리됨
# ✅ [완료] 배우 492: '배우 이영준, 성별: male, 나이: 25, 키: 183cm, 몸무게: 63kg' 처리됨
# ✅ [완료] 배우 493: '배우 한봉수, 성별: male, 나이: 57, 키: 173cm, 몸무게: 69kg' 처리됨
# ✅ [완료] 배우 494: '배우 정재용, 성별: male, 나이: 47, 키: 182cm, 몸무게: 85kg' 처리됨
# ✅ [완료] 배우 495: '배우 박권혁, 성별: male, 나이: 25, 키: 190cm, 몸무게: 72kg' 처리됨
# ✅ [완료] 배우 496: '배우 위창우, 성별: male, 나이: 28, 키: 179cm, 몸무게: 67kg' 처리됨
# ✅ [완료] 배우 497: '배우 우승곤, 성별: male, 나이: 37, 키: 176cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 498: '배우 유영석, 성별: male, 나이: 30, 키: 181cm, 몸무게: 73kg' 처리됨
# ✅ [완료] 배우 499: '배우 박병규, 성별: male, 나이: 26, 키: 177cm, 몸무게: 70kg' 처리됨
# ✅ [완료] 배우 500: '배우 김은진, 성별: male, 나이: 60, 키: 178cm, 몸무게: 77kg' 처리됨
# 🔄 [배치 처리] 남은 20명 처리 중...
# 📌 [벡터 크기 확인] KoCLIP 벡터 차원: 768 (정상: 768)
#
# ✅ 배우 500명의 특징 벡터가 CSV에 저장되었습니다.

# %% [markdown]
# #### Python 및 JavaScript를 이용해 유사도 비교 결과 확인

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# CSV 파일 로드
csv_path = "actor_features.csv"
df = pd.read_csv(csv_path)

# 특징 벡터만 추출
actor_ids = df["actor_id"].tolist()
main_infos = df["main_info"].tolist()
features = df.iloc[:, 2:].values  # 768차원 벡터 부분

# 특정 배우와 유사한 배우 찾기
def find_similar_actors(target_actor_id, top_n=3):
    if target_actor_id not in actor_ids:
        print(f"❌ 배우 {target_actor_id} 정보를 찾을 수 없습니다.")
        return

    # 해당 배우의 정보 가져오기
    idx = actor_ids.index(target_actor_id)
    target_vector = features[idx].reshape(1, -1)  # 1x768 형태
    target_info = main_infos[idx]

    # 모든 배우와의 코사인 유사도 계산
    similarities = cosine_similarity(target_vector, features)[0]

    # 본인 제외하고 유사한 배우 top_n 선정
    similar_indices = np.argsort(similarities)[::-1]  # 유사도 높은 순 정렬
    similar_indices = [i for i in similar_indices if actor_ids[i] != target_actor_id][:top_n]

    # 비교 대상 배우 정보 출력
    print(f"\n🎭 [유사도를 비교할 배우]")
    print(f"배우 {target_actor_id} - {target_info}")

    # 결과 출력
    print(f"\n🎭 [배우 {target_actor_id}와 유사한 배우 TOP {top_n}]")
    for rank, i in enumerate(similar_indices, start=1):
        print(f"{rank}. 배우 {actor_ids[i]} ({main_infos[i]}) - 유사도: {similarities[i]:.4f}")

# 비교할 배우 번호 설정
target_actor_id = 400  # 원하는 배우 번호 입력
find_similar_actors(target_actor_id)
# Out:
# 🎭 [유사도를 비교할 배우]
# 배우 400 - 배우 강다빈, 성별: male, 나이: 33, 키: 188cm, 몸무게: 83kg
#
# 🎭 [배우 400와 유사한 배우 TOP 3]
# 1. 배우 457 (배우 강희건, 성별: male, 나이: 30, 키: 184cm, 몸무게: 80kg) - 유사도: 0.9837
# 2. 배우 115 (배우 강영원, 성별: male, 나이: 34, 키: 175cm, 몸무게: 75kg) - 유사도: 0.9815
# 3. 배우 218 (배우 강슬기, 성별: male, 나이: 27, 키: 181cm, 몸무게: 89kg) - 유사도: 0.9796

# %%
js_code = """
const fs = require("fs");
const csv = require("csv-parser");
const cosineSimilarity = require("cosine-similarity");

const actorData = {}; // { actor_id: { mainInfo, features } }

fs.createReadStream("actor_features.csv")
  .pipe(csv())
  .on("data", (row) => {
    if (!row.actor_id || !row.main_info) return; // 필수 값 체크

    const actorId = parseInt(row.actor_id);
    const mainInfo = row.main_info;

    // 특징 벡터 추출
    const features = Object.keys(row)
      .filter((key) => key.startsWith("feature_"))
      .map((key) => Number(row[key]));

    if (features.length !== 768) {
      console.warn(`⚠️ 배우 ${actorId}의 특징 벡터 크기가 768이 아닙니다. 데이터 무시.`);
      return;
    }

    actorData[actorId] = { mainInfo, features };
  })
  .on("end", () => {
    console.log(`✅ 총 ${Object.keys(actorData).length}명의 배우 데이터 로드 완료!`);
    findSimilarActors(400); // 특정 배우와 유사한 배우 찾기 실행
  });

function findSimilarActors(targetActorId, topK = 3) {
  if (!actorData[targetActorId]) {
    console.error(`❌ 배우 ${targetActorId}의 데이터가 없습니다.`);
    return;
  }

  const targetMainInfo = actorData[targetActorId].mainInfo;
  console.log(`\n🔹 배우 ${targetActorId} (${targetMainInfo})\n`);

  const targetVector = actorData[targetActorId].features;
  const similarities = [];

  for (const [actorId, { mainInfo, features }] of Object.entries(actorData)) {
    if (parseInt(actorId) === targetActorId) continue;
    const similarity = cosineSimilarity(targetVector, features);
    similarities.push({ actorId: parseInt(actorId), mainInfo, similarity });
  }

  similarities.sort((a, b) => b.similarity - a.similarity);
  const topActors = similarities.slice(0, topK);

  console.log(`🎭 배우 ${targetActorId}와 가장 유사한 ${topK}명의 배우:`);
  console.table(topActors);
}
"""

# script.js 파일로 저장
with open("script.js", "w") as f:
    f.write(js_code)

print("✅ script.js 파일이 생성되었습니다.")
# Out:
# ✅ script.js 파일이 생성되었습니다.

# %%
# 필요한 패키지 설치
# !npm install csv-parser cosine-similarity
# Out:
# ⠙⠹⠸
# up to date, audited 3 packages in 754ms
# ⠸
# found 0 vulnerabilities
# ⠸

# %%
# !node script.js
